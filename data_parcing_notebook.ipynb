# %% [markdown]
# **Data Parcing flow**

# %% [markdown]
# Importing necessary libraries and modules

# %%
import csv
import re
from pprint import pprint

# %% [markdown]
# Open file: "source_data/Input_File_01.txt"

# %%
try:
    with open("source_data/Input_File_01.txt", 'rb') as f:
        content = f.read()
except FileNotFoundError:
    print(f"Error: Input file not found at 'source_data/Input_File_01.txt'")

# %% [markdown]
# Parsing and Record Extraction. The content is split by the null delimiter. We decode using 'latin-1' because it can represent every possible byte, preventing errors with mixed text/binary data. Empty fields resulting from the split are filtered out.

# %%
fields = content.split(b'\\x00')   # split by null byte
all_fields = []                   # make an empty list

for field in fields:
    if field:  # skip empty parts
        text = field.decode('latin-1')  # convert bytes → string
        text = text.strip()             # remove spaces/newlines
        all_fields.append(text)         # add to the list

pprint(all_fields)
# Out:
# ['1',
#  'X530108146000',
#  'INTERNAL RETAINING RING',
#  "ANNEAU D\\'ARRET POUR ALESAGE",
#  'INNENHALTERING',
#  'ANELLO DI SICUREZZA INTERNO',
#  'ANILLO DE RETENCION INTERNO',
#  'PIER\\xc5\\x9aCIE\\xc5\\x83 USTALAJ\\xc4\\x84CY WEWN\\xc4\\x98TRZNY',
#  'X530.108.146.000',
#  '72311106',
#  'DIN472 - 90X3',
#  '2',
#  '139100150130',
#  'SHIM RING',
#  'ANNEAU ENTRETOISE',
#  'UNTERLEGRING',
#  'DISCO SPESSORE',
#  'ANILLO DE CALCE',
#  'PIER\\xc5\\x9aCIE\\xc5\\x83 REGULACYJNY',
#  '139.100.150.130',
#  '72316227',
#  '0,10 MM',
#  '139100150131',
#  '139.100.150.131',
#  '72316228',
#  '0,15 MM',
#  '139100150132',
#  '139.100.150.132',
#  '72316229',
#  '0,25 MM',
#  '139100150133',
#  '139.100.150.133',
#  '72316230',
#  '0,30 MM',
#  '139100150134',
#  '139.100.150.134',
#  '72316231',
#  '0,80 MM',
#  '3',
#  'X548967266000',
#  'O-RING',
#  'JOINT TORIQUE',
#  'GIUNTO DI TENUTA',
#  'JUNTA TOROIDAL',
#  'X548.967.266.000',
#  '72313499',
#  '82,14X3,53-NBR 70 FWN56402',
#  '4',
#  '178100010020',
#  'SEALING COVER',
#  'CACHE ETANCHE',
#  'DICHTDECKEL',
#  'COPERTURA TENUTA',
#  'CUBIERTA SELLANTE',
#  'POKRYWA USZCZELNIAJ\\xc4\\x84CA',
#  '178.100.010.020',
#  '72393065',
#  '5',
#  'X550081705000',
#  'SHAFT SEAL',
#  "JOINT D\\'ARBRE",
#  'WELLENDICHTUNG',
#  'TENUTA ALBERO',
#  'SELLO DE EJE',
#  'USZCZELNIENIE WA\\xc5\\x81U',
#  'X550.081.705.000',
#  '72430070',
#  'FWN65500-DGS40X56X8/10WDF02',
#  '6',
#  'X619049041009',
#  'TAPER ROLLER BEARING',
#  'PALIER A ROULEMENT CONIQUE',
#  'KEGELROLLENLAGER',
#  'CUSCINETTO A RULLI CONICI',
#  'RODAMIENTO DE RODILLOS CONICO',
#  '\\xc5\\x81O\\xc5\\xbbYSKO ROLKOWE STO\\xc5\\xbbKOWE',
#  'X619.049.041.009',
#  '72317208',
#  'DIN 720',
#  '7',
#  'H238104010040',
#  'DIFFERENTIAL LOCK',
#  'VERROUILLAGE DIFFERENTIEL',
#  'DIFFERENTIAL SPERRE',
#  'BLOCCO DIFFERENZIALE',
#  'BLOQUEO DEL DIFERENCIAL',
#  'BLOKADA MECHANIZMU R\\xc3\\x93\\xc5\\xbbNICOWEGO',
#  'H238.104.010.040',
#  '72359217',
#  '8',
#  'X487535406000',
#  'HEXAGONAL HEAD BOLT',
#  'VIS A T\\xc3\\x8aTE HEXAGONALE',
#  'SECHSKANTSCHRAUBE',
#  'VITE A TESTA ESAGONALE',
#  'TORNILLO DE CABEZA HEXAGONAL',
#  '\\xc5\\x9aRUBA SZE\\xc5\\x9aCIOK\\xc4\\x84TNA',
#  'X487.535.406.000',
#  '72374463',
#  'DIN 933 M12X25 GWA-10.9',
#  '9',
#  '278110011030',
#  'BEARING FLANGE',
#  'FLASQUE ROULEMENT',
#  'LAGERFLANSCH',
#  'FLANGIA DEL CUSCINETTO',
#  'BRIDA DE COJINETE',
#  'KRYZA \\xc5\\x81O\\xc5\\xbbYSKA',
#  '278.110.011.030',
#  '72403994',
#  '10',
#  '514100010130',
#  'DISC',
#  'DISQUE',
#  'SCHEIBE',
#  'DISCO',
#  'TARCZA',
#  '514.100.010.130',
#  '72317260',
#  '11',
#  '278110011050',
#  'DIFFERENTIAL SIDE GEAR',
#  'ENGRENAGE LAT\\xc3\\x89RAL DE DIFF\\xc3\\x89RENTIEL',
#  'ACHSKEGELRAD',
#  'INGRANAGGIO SATELLITE DIFFERENZIALE',
#  'ENGRANAJE LATERAL DIFERENCIAL',
#  'KO\\xc5\\x81O Z\\xc4\\x98BATE BOCZNE MECHANIZMU R\\xc3\\x93\\xc5\\xbbNIC.',
#  '278.110.011.050',
#  '72403996',
#  '*22\\n<-- U148.100.110  1X',
#  'SERBLK',
#  '12',
#  '278110011040',
#  '278.110.011.040',
#  '72403995',
#  '13',
#  '178100010040',
#  'CROSS BEARING',
#  'PALIER TRANSVERSAL',
#  'KREUZLAGER',
#  'CUSCINETTO CROCIERA',
#  'RODAMIENTO TRANSVERSAL',
#  '\\xc5\\x81O\\xc5\\xbbYSKO POPRZECZNE',
#  '178.100.010.040',
#  '72316723',
#  '14',
#  '199100010020',
#  'AXLE',
#  'ESSIEU',
#  'ACHSE',
#  'ASSALE',
#  'EJE',
#  'O\\xc5\\x9a',
#  '199.100.010.020',
#  '72310138',
#  '15',
#  '278110011120',
#  'DIFFERENTIAL PINION',
#  'PIGNON DE DIFF\\xc3\\x89RENTIEL',
#  'AUSGLEICHSKEGELRAD',
#  'PIGNONE DIFFERENZIALE',
#  'PINON DEL DIFERENCIAL',
#  'Z\\xc4\\x98BNIK MECHANIZMU R\\xc3\\x93\\xc5\\xbbNICOWEGO',
#  '278.110.011.120',
#  '72312406',
#  '*11\\n<-- U148.100.110  1X',
#  '16',
#  '514100010100',
#  '514.100.010.100',
#  '72317257',
#  '1,0 MM',
#  '514100010110',
#  '514.100.010.110',
#  '72317258',
#  '1,2 MM',
#  '514100010120',
#  '514.100.010.120',
#  '72317259',
#  '1,5 MM',
#  '17',
#  'X500621846000',
#  'TENSIONING PIN',
#  'BROCHE DE TENSIONNEMENT',
#  'SPANNSTIFT',
#  'PERNO TENSIONE',
#  'PERNO TENSOR',
#  'TRZPIE\\xc5\\x83 ROZPR\\xc4\\x98\\xc5\\xbbNY',
#  'X500.621.846.000',
#  '72313811',
#  'ISO8752 5X30-ST VDA42',
#  '18',
#  'X500610446000',
#  'X500.610.446.000',
#  '72313798',
#  'ISO8752-3X30-A-ST-OB3 FWN10256',
#  '19',
#  '210103011040',
#  '210.103.011.040',
#  '72435674',
#  '20',
#  'SIEHE WECHSELGETRIEBE',
#  'SEE GEAR BOX (CHANGE-SPEED)',
#  'VER CAJA DE CAMBIOS',
#  'VOIR BOITE DE VITESSE',
#  'VEDI CAMBIO',
#  'PATRZ SKRZYNIA BIEG\\xc3\\x93W (ZMIANA BIEG\\xc3\\x93W)',
#  '21',
#  '168109010010',
#  'DIFFERENTIAL HOUSING',
#  'CARTER DE DIFF\\xc3\\x89RENTIEL',
#  'DIFFERENTIALGEH\\xc3\\x84USE',
#  'SCATOLA DIFFERENZIALE',
#  'ALOJAMIENTO DIFERENCIAL',
#  'OBUDOWA MECHANIZMU R\\xc3\\x93\\xc5\\xbbNICOWEGO',
#  '168.109.010.010',
#  '72392781',
#  '22',
#  '23',
#  'X623138320000',
#  'X623.138.320.000',
#  '72378806',
#  '24',
#  '25',
#  '178100010050',
#  'KEYED WASHER',
#  'RONDELLE CLAVET\\xc3\\x89E',
#  'EINSTELLSCHEIBE',
#  'RONDELLA MASCHIATA',
#  'ARANDELA ENCHAVETADA',
#  'PODK\\xc5\\x81ADKA Z WYPUSTEM',
#  '178.100.010.050',
#  '72393067',
#  '178100010051',
#  '178.100.010.051',
#  '72393068',
#  '178100010052',
#  '178.100.010.052',
#  '72393069',
#  '0,20 MM',
#  '178100010053',
#  '178.100.010.053',
#  '72393070',
#  '26',
#  'X549284566000',
#  'X549.284.566.000',
#  '72376717',
#  '101X3-NBR 70 FWN56402',
#  '27',
#  '205100011091',
#  'BEARING CAP',
#  'CHAPEAU DE PALIER',
#  'LAGERKAPPE',
#  'CAPPELLO DEL SUPPORTO',
#  'TAPA DE COJINETE',
#  'POKRYWA \\xc5\\x81O\\xc5\\xbbYSKA',
#  '205.100.011.091',
#  '72397528',
#  '28',
#  'X487531806000',
#  'X487.531.806.000',
#  '72315688',
#  'M10 X 35 CL10.9',
#  '29',
#  'X493613205000',
#  'SOCKET HEAD BOLT',
#  'BOULON \\xc3\\x80 T\\xc3\\x8aTE CREUSE',
#  'ZYLINDERSCHRAUBE',
#  'BULLONE CON TESTA A BRUGOLA',
#  'PERNO DE CABEZA HEXAGONAL',
#  '\\xc5\\x9aRUBA IMBUSOWA',
#  'X493.613.205.000',
#  '72315778',
#  '33',
#  '258100010080',
#  'SHIFT FORK',
#  'FOURCHETTE DE D\\xc3\\x89BRAYAGE',
#  'SCHALTGABEL',
#  'FORCHETTA DEL CAMBIO',
#  'HORQUILLA EMBRAGUE',
#  'WIDE\\xc5\\x81KI WYBIERAKA',
#  '258.100.010.080',
#  '72401949',
#  '<>34\\n<>',
#  'X418852204000',
#  'DOWEL PIN',
#  'TENON DE GUIDAGE',
#  'PASSSTIFT',
#  'SPINA DI CENTRAGGIO',
#  'PASADOR DE ESPIGA',
#  'KO\\xc5\\x81EK USTALAJ\\xc4\\x84CY',
#  'X418.852.204.000',
#  '72372672',
#  'DIN 1474-8X20-ST',
#  '34',
#  '35',
#  '238104010240',
#  'SLIDING MEMBER',
#  'DISPOSITIF DE GLISSAGE',
#  'GLEITSTEIN',
#  'MEMBRO SCORREVOLE',
#  'ELEMENTO DESLIZANTE',
#  'ELEMENT \\xc5\\x9aLIZGOWY',
#  '238.104.010.240',
#  '72399554',
#  '36',
#  'X413425806000',
#  'THREADED PIN',
#  'BROCHE FILET\\xc3\\x89E',
#  'GEWINDESTIFT',
#  'PERNO FILETTATO',
#  'PERNO ROSCADO',
#  'SWORZE\\xc5\\x83 GWINTOWANY',
#  'X413.425.806.000',
#  '72372595',
#  'DIN 915 M12X20-45H',
#  '37',
#  'X548854466000',
#  'X548.854.466.000',
#  '72313440',
#  '18X2,5-NBR 70 FWN56402',
#  '38',
#  'X446217334000',
#  'FITTING KEY',
#  'CL\\xc3\\x89 DE FIXATION',
#  'PASSFEDER',
#  'LINGUETTA',
#  'LLAVE DE ENCAJE',
#  'KLUCZ MONTA\\xc5\\xbbOWY',
#  'X446.217.334.000',
#  '72373227',
#  'DIN 6885 A8X5X36-C45K',
#  '39',
#  'H178109010023',
#  'BLOCKING LEVER',
#  'LEVIER DE BLOCAGE',
#  'SPERRHEBEL',
#  'LEVA DI BLOCCO',
#  'PALANCA DE BLOQUEO',
#  'D\\xc5\\xb9WIGNIA BLOKUJ\\xc4\\x84CA',
#  'H178.109.010.023',
#  '72355684',
#  '40',
#  'X413627906000',
#  'X413.627.906.000',
#  '72372608',
#  'DIN 916 M14X16-45H',
#  '41',
#  'X506240500000',
#  'CYLINDER PIN',
#  'GOUPILLE DE V\\xc3\\x89RIN',
#  'ZYLINDERSTIFT',
#  'PERNO CILINDRO',
#  'PERNO DEL CILINDRO',
#  'CZOP CYLINDRA',
#  'X506.240.500.000',
#  '72313870',
#  'DIN 6325 6M6X36',
#  '42',
#  '016861050230',
#  'COMPRESSION SPRING',
#  'RESSORT DE COMPRESSION',
#  'DRUCKFEDER',
#  'MOLLA COMPRESSIONE',
#  'RESORTE DE COMPRESI\\xc3\\x93N',
#  'SPR\\xc4\\x98\\xc5\\xbbYNA DOCISKOWA',
#  '016.861.050.230',
#  '72386498',
#  '43',
#  '178109360010',
#  'PRESSURE SWITCH',
#  'MANOCONTACT',
#  'DRUCKSCHALTER',
#  'PRESSOSTATO',
#  'INTERRUPTOR DE PRESION',
#  'PRZE\\xc5\\x81\\xc4\\x84CZNIK CI\\xc5\\x9aNIENIA',
#  '178.109.360.010',
#  '72393606',
#  '44',
#  'X540003878000',
#  'SEALING WASHER',
#  'RONDELLE ETANCH.',
#  'DICHTRING',
#  'RONDELLA ERMETIC',
#  'ARANDELA SELLO',
#  'PODK\\xc5\\x81ADKA USZCZELNIAJ\\xc4\\x84CA',
#  'X540.003.878.000',
#  '72315093',
#  'DIN 7603 A12X18-CU',
#  '45',
#  '178109010020',
#  'BOLT',
#  'BOULON',
#  'BOLZEN',
#  'BULLONE',
#  'PERNO',
#  '\\xc5\\x9aRUBA',
#  '178.109.010.020',
#  '72393538',
#  '46',
#  'X500625546000',
#  'X500.625.546.000',
#  '72375154',
#  'ISO8752-6X50-A-ST-OB3',
#  '47',
#  '178109010011',
#  'ECCENTRIC',
#  'EXCENTRIQUE',
#  'EXZENTER',
#  'ECCENTRICO',
#  'EXCENTRICO',
#  'MIMO\\xc5\\x9aR\\xc3\\x93D',
#  '178.109.010.011',
#  '72393537',
#  '50',
#  '380100010010',
#  'LUBRICATING OIL PIPE',
#  "TUYAU D\\'HUILE DE GRAISSAGE",
#  'SCHMIERROHR',
#  'TUBO DI LUBRIFICAZIONE',
#  'TUBERIA DE ACEITE LUBRICACION',
#  'PRZEW\\xc3\\x93D SZTYWNY OLEJU SMAROWEGO',
#  '380.100.010.010',
#  '72408558',
#  '51',
#  'X548823666000',
#  'X548.823.666.000',
#  '72313418',
#  '9,3X2,4-NBR 70 FWN56402',
#  '52',
#  'H205100011010',
#  'PAN',
#  'RECEPTEUR',
#  'AUFFANGWANNE',
#  'PANNELLO',
#  'CUBA',
#  'MISA',
#  'H205.100.011.010',
#  '72357985',
#  '53',
#  '205100011050',
#  'BAFFLE',
#  'CHICANE',
#  'PRALLBLECH',
#  'DEVIATORE',
#  'DESVIADOR',
#  'PRZEGRODA',
#  '205.100.011.050',
#  '72397526',
#  '54',
#  'X428803604000',
#  'NUT',
#  '\\xc3\\x89CROU',
#  'MUTTER',
#  'DADO',
#  'TUERCA',
#  'NAKR\\xc4\\x98TKA',
#  'X428.803.604.000',
#  '72372883',
#  'DIN 936 M14-17H',
#  '55',
#  'X487520041000',
#  'X487.520.041.000',
#  '72315626',
#  'DIN 933-M6 X 16-8.8-A3L',
#  '56',
#  'X450005108000',
#  'X450.005.108.000',
#  '72311787',
#  'DIN 125-6,4-ST.A3L',
#  '57',
#  'X428202239000',
#  'X428.202.239.000',
#  '72313266',
#  'DIN 934 M6-8A3L',
#  '58',
#  'X454305108000',
#  'X454.305.108.000',
#  '72311822',
#  'DIN9021-6,4-140HV-A3L',
#  '59',
#  'H162160010010',
#  'OIL LUBE PIPE',
#  "TUYAU D\\'HUILE DE LUBRIFICATION",
#  '\\xc3\\x96LSCHMIERROHR',
#  'TUBO DI LUBRIFICAZIONE A OLIO',
#  'TUBERIA DE ACEITE LUBRICANTE',
#  'RURKA SMAROWANIA OLEJEM',
#  'H162.160.010.010',
#  '72355006',
#  '60',
#  'X428802404000',
#  'X428.802.404.000',
#  '72372870',
#  'DIN 936 M8-17H',
#  'X413122106000',
#  'X413.122.106.000',
#  '72372576',
#  'DIN 914 M8X35-45H',
#  '61',
#  'X450006308000',
#  'X450.006.308.000',
#  '72311788',
#  'DIN 125-8,4-ST.A3L',
#  '7169',
#  'k',
#  '\\x10',
#  '\\x01',
#  'D',
#  '\\x01',
#  '\\r',
#  '\\x12',
#  'f',
#  '\\x1e',
#  'C',
#  '\\x02\\x1b',
#  '\\x02',
#  '\\x01',
#  '\\x8b\\x07t\\x01\\xb2\\x07\\x92\\x01\\xff\\xff\\xff\\xff',
#  '\\xbc\\x1b',
#  '\\x02',
#  '\\x01',
#  'I\\x08\\x9d\\x01p\\x08\\xbb\\x01\\xff\\xff\\xff\\xff',
#  'A\\x19',
#  '\\x02',
#  '\\x01',
#  '\\x8d\\x06\\xa9\\x01\\xb0\\x06\\xc6\\x01\\xff\\xff\\xff\\xff',
#  '\\x86\\x1a',
#  '\\x02',
#  '\\x01',
#  '{\\x07\\xff\\x01\\xa3\\x07\\x1d\\x02\\xff\\xff\\xff\\xff',
#  '\\x86\\x1a',
#  '\\x02',
#  '\\x01',
#  ')\\x07\\x19\\x02P\\x077\\x02\\xff\\xff\\xff\\xff',
#  '\\xc5\\x01',
#  '\\x02',
#  '\\x01',
#  '\\x84\\x01&\\x02\\x99\\x01B\\x02\\xff\\xff\\xff\\xff',
#  'H\\x1a',
#  '\\x02',
#  '\\x01',
#  "\\x01\\x07+\\x02\\'\\x07I\\x02\\xff\\xff\\xff\\xff",
#  '\\r\\x03',
#  '\\x02',
#  '\\x01',
#  '\\xbd\\x01C\\x02\\xd1\\x01`\\x02\\xff\\xff\\xff\\xff',
#  '\\x87\\x03',
#  '\\x02',
#  '\\x01',
#  '\\xfb\\x01a\\x02\\x0c\\x02~\\x02\\xff\\xff\\xff\\xff',
#  '\\x12\\x04',
#  '\\x02',
#  '\\x01',
#  '+\\x02y\\x02=\\x02\\x96\\x02\\xff\\xff\\xff\\xff',
#  '\\x05\\x1a',
#  '\\x02',
#  '\\x01',
#  'Y\\x06\\x7f\\x02}\\x06\\x9c\\x02\\xff\\xff\\xff\\xff',
#  '\\xaf\\x04',
#  '\\x02',
#  '\\x01',
#  'j\\x02\\x9b\\x02~\\x02\\xb9\\x02\\xff\\xff\\xff\\xff',
#  '\\xe8\\x18',
#  '\\x02',
#  '\\x01',
#  '\\xa5\\x06\\xb2\\x02\\xcb\\x06\\xd0\\x02\\xff\\xff\\xff\\xff',
#  'v\\x05',
#  '\\x02',
#  '\\x01',
#  '\\xad\\x02\\xd9\\x02\\xbf\\x02\\xf6\\x02\\xff\\xff\\xff\\xff',
#  '\\x91\\r',
#  '\\x02',
#  '\\x01',
#  '\\x1e\\x05\\xe6\\x02D\\x05\\x04\\x03\\xff\\xff\\xff\\xff',
#  '\\x05\\x1a',
#  '\\x02',
#  '\\x01',
#  '"\\x07\\xf2\\x02I\\x07\\x10\\x03\\xff\\xff\\xff\\xff',
#  '\\xea\\x17',
#  '\\x02',
#  '\\x01',
#  '\\x92\\x06\\x19\\x03\\xb8\\x066\\x03\\xff\\xff\\xff\\xff',
#  '\\xf7\\x06',
#  '\\x02',
#  '\\x01',
#  '?\\x03?\\x03S\\x03]\\x03\\xff\\xff\\xff\\xff',
#  '\\xbd\\x15',
#  '\\x02',
#  '\\x01',
#  '\\xc4\\x01d\\x03\\xe9\\x01\\x81\\x03\\xff\\xff\\xff\\xff',
#  'L\\x16',
#  '\\x02',
#  '\\x01',
#  '\\x02\\x02\\x85\\x03#\\x02\\xa2\\x03\\xff\\xff\\xff\\xff',
#  '\\xef\\x16',
#  '\\x02',
#  '\\x01',
#  'D\\x02\\xb2\\x03i\\x02\\xd0\\x03\\xff\\xff\\xff\\xff',
#  'L\\x12',
#  '\\x02',
#  '\\x01',
#  '\\xa1\\x03\\xd1\\x03\\xc8\\x03\\xee\\x03\\xff\\xff\\xff\\xff',
#  'I\\x14',
#  '\\x02',
#  '\\x01',
#  '\\x16\\x01\\xfe\\x03>\\x01\\x1d\\x04\\xff\\xff\\xff\\xff',
#  '\\xe6\\x12',
#  '\\x02',
#  '\\x01',
#  '\\xee\\x02\\x02\\x04\\x15\\x03\\x1f\\x04\\xff\\xff\\xff\\xff',
#  '\\x84\\x10',
#  '\\x02',
#  '\\x01',
#  '\\xb9\\x03\\x10\\x04\\xdc\\x03.\\x04\\xff\\xff\\xff\\xff',
#  '\\x94\\r',
#  '\\x02',
#  '\\x01',
#  'O\\x07$\\x04u\\x07B\\x04\\xff\\xff\\xff\\xff',
#  '\\xbf\\r',
#  '\\x02',
#  '\\x01',
#  'U\\x07O\\x04w\\x07m\\x04\\xff\\xff\\xff\\xff',
#  '\\xc2\\r',
#  '\\x02',
#  '\\x01',
#  '\\x9e\\x07P\\x04\\xc6\\x07m\\x04\\xff\\xff\\xff\\xff',
#  '\\x81\\x17',
#  '\\x02',
#  '\\x01',
#  '\\xf6\\x01S\\x04\\x1c\\x02q\\x04\\xff\\xff\\xff\\xff',
#  '\\xd3\\x0e',
#  '\\x02',
#  '\\x01',
#  '\\xcc\\x07r\\x04\\xf3\\x07\\x90\\x04\\xff\\xff\\xff\\xff',
#  '\\xda\\x0f',
#  '\\x02',
#  '\\x01',
#  '\\x89\\x08x\\x04\\xb0\\x08\\x96\\x04\\xff\\xff\\xff\\xff',
#  '\\x14\\x0f',
#  '\\x02',
#  '\\x01',
#  "\\xff\\x07\\x95\\x04\\'\\x08\\xb3\\x04\\xff\\xff\\xff\\xff",
#  '\\xba\\x11',
#  '\\x02',
#  '\\x01',
#  '\\x96\\x03\\x9d\\x04\\xbc\\x03\\xba\\x04\\xff\\xff\\xff\\xff',
#  '\\xbb\\x13',
#  '\\x02',
#  '\\x01',
#  '\\x0c\\x02\\xa4\\x043\\x02\\xc2\\x04\\xff\\xff\\xff\\xff',
#  '\\xba\\x11',
#  '\\x02',
#  '\\x01',
#  'K\\x03\\xb5\\x04q\\x03\\xd2\\x04\\xff\\xff\\xff\\xff',
#  '\\xb7\\x11',
#  '\\x02',
#  '\\x01',
#  '\\xed\\x02\\xcc\\x04\\x11\\x03\\xe9\\x04\\xff\\xff\\xff\\xff',
#  '\\x15',
#  '\\x02',
#  '\\x01',
#  '\\x1f\\x01\\xf2\\x04C\\x01\\x10\\x05\\xff\\xff\\xff\\xff',
#  'D\\x0c',
#  '\\x02',
#  '\\x01',
#  '\\xf6\\x05\\x1b\\x05\\x1c\\x069\\x05\\xff\\xff\\xff\\xff',
#  '\\xa2\\x19',
#  '\\x02',
#  '\\x01',
#  '\\xf1\\x06\\xaf\\x01\\x16\\x07\\xcd\\x01\\xff\\xff\\xff\\xff',
#  '\\xee',
#  '\\x02',
#  '\\x01',
#  'P\\x01\\x0c\\x02[\\x01)\\x02\\xff\\xff\\xff\\xff',
#  '\\xa3\\n',
#  '\\x02',
#  '\\x01',
#  '\\xfc\\x02\\x8e\\x01\\x19\\x03\\xac\\x01\\xff\\xff\\xff\\xff',
#  '\\xd5\\t',
#  '\\x02',
#  '\\x01',
#  'R\\x03k\\x01r\\x03\\x88\\x01\\xff\\xff\\xff\\xff',
#  '\\x8b\\t',
#  '\\x02',
#  '\\x01',
#  '\\xb6\\x03y\\x01\\xcf\\x03\\x97\\x01\\xff\\xff\\xff\\xff',
#  '\\xf6\\x08',
#  '\\x02',
#  '\\x01',
#  '\\xeb\\x03I\\x01\\x08\\x04g\\x01\\xff\\xff\\xff\\xff',
#  '\\xa3\\n',
#  '\\x02',
#  '\\x01',
#  '\\x8c\\x04\\xcc',
#  '\\xaa\\x04\\xe9',
#  '\\xff\\xff\\xff\\xff',
#  '\\xd5\\t',
#  '\\x02',
#  '\\x01',
#  '\\x91\\x04\\x0c\\x01\\xaf\\x04*\\x01\\xff\\xff\\xff\\xff',
#  '\\x8b\\t',
#  '\\x02',
#  '\\x01',
#  '\\xb2\\x04;\\x01\\xca\\x04Y\\x01\\xff\\xff\\xff\\xff',
#  '\\xd5\\t',
#  '\\x02',
#  '\\x01',
#  '\\x16\\x05\\x03\\x014\\x05 \\x01\\xff\\xff\\xff\\xff',
#  '\\xa3\\n',
#  '\\x02',
#  '\\x01',
#  '_\\x05\\xf8',
#  '|\\x05\\x16\\x01\\xff\\xff\\xff\\xff',
#  '-\\x0b',
#  '\\x02',
#  '\\x01',
#  '\\xc6\\x04\\xd6\\x01\\xe3\\x04\\xf3\\x01\\xff\\xff\\xff\\xff',
#  '\\xd1\\x0b',
#  '\\x02',
#  '\\x01',
#  '\\x04\\x05\\xf5\\x01 \\x05\\x12\\x02\\xff\\xff\\xff\\xff',
#  '\\x1b\\x0c',
#  '\\x02',
#  '\\x01',
#  '\\x84\\x04B\\x02\\xa2\\x04a\\x02\\xff\\xff\\xff\\xff',
#  '\\xd5\\t',
#  '\\x02',
#  '\\x01',
#  '\\xa3\\x04Z\\x04\\xc3\\x04w\\x04\\xff\\xff\\xff\\xff',
#  '\\x86\\x07',
#  '\\x02',
#  '\\x01',
#  '\\xb8\\x04\\xd2\\x03\\xd6\\x04\\xf0\\x03\\xff\\xff\\xff\\xff',
#  '\\xcd\\x08',
#  '\\x02',
#  '\\x01',
#  '\\x84\\x04\\xcd\\x03\\xa2\\x04\\xeb\\x03\\xff\\xff\\xff\\xff',
#  '\\xd7\\x0c',
#  '\\x02',
#  '\\x01',
#  '\\x0c\\x05\\x8c\\x04+\\x05\\xa9\\x04\\xff\\xff\\xff\\xff',
#  '\\xa3\\n',
#  '\\x02',
#  '\\x01',
#  '\\xa1\\x04\\xa5\\x04\\xc0\\x04\\xc3\\x04\\xff\\xff\\xff\\xff',
#  '\\xd0\\x07',
#  '\\x02',
#  '\\x01',
#  '\\xde\\x03|\\x03\\xf5\\x03\\x9a\\x03\\xff\\xff\\xff\\xff',
#  '\\x86\\x07',
#  '\\x02',
#  '\\x01',
#  '\\x89\\x03H\\x03\\xa6\\x03f\\x03\\xff\\xff\\xff\\xff',
#  '.\\x06',
#  '\\x02',
#  '\\x01',
#  '\\x95\\x022\\x03\\xa9\\x02O\\x03\\xff\\xff\\xff\\xff',
#  '(\\x13',
#  '\\x02',
#  '\\x01',
#  'u\\x02\\x11\\x04\\x9d\\x02/\\x04\\xff\\xff\\xff\\xff',
#  '@\\x17',
#  '\\x02',
#  '\\x01',
#  '\\x04\\x02-\\x04)\\x02K\\x04\\xff\\xff\\xff\\xff',
#  '\\x87\\x14',
#  '\\x02',
#  '\\x01',
#  '"\\x01\\xbc\\x04@\\x01\\xd8\\x04\\xff\\xff\\xff\\xff',
#  '0\\x1c',
#  '\\x02',
#  '\\x01',
#  'H\\x08\\xc0\\x01g\\x08\\xdd\\x01\\xff\\xff\\xff\\xff',
#  '\\xc1\\x1a',
#  '\\x02',
#  '\\x01',
#  'V\\x07\\xdb\\x02{\\x07\\xf9\\x02\\xff\\xff\\xff\\xff',
#  '\\xa5\\x18',
#  '\\x02',
#  '\\x01',
#  '\\xbe\\x06\\x01\\x03\\xdd\\x06\\x1e\\x03\\xff\\xff\\xff\\xff',
#  '\\x9f\\x0f',
#  '\\x02',
#  '\\x01',
#  '\\xab\\x08:\\x05\\xd2\\x08X\\x05\\xff\\xff\\xff\\xff',
#  'g',
#  '\\x0e',
#  '\\x01',
#  'n\\x1c',
#  '\\x01',
#  'h\\t\\x18\\x06',
#  '\\x01h',
#  '\\x14',
#  '\\x08',
#  '\\xfe\\xff\\x01',
#  '\\xff\\xff\\xd4',
#  '\\x01',
#  '\\xdb',
#  '\\xe1',
#  '\\xfe\\xff\\x01',
#  '\\xff\\xff\\xd4',
#  '\\x01',
#  '\\xe7',
#  '\\xe7',
#  '\\xfe\\xff\\x03',
#  '\\x0e',
#  '\\xd4',
#  '\\x01',
#  '\\xdb',
#  '\\xe1',
#  '\\xfe\\xff\\x03',
#  '\\x0f',
#  '\\xc6\\x08',
#  '\\x01',
#  '\\xc6\\x08',
#  '\\xc6\\x08',
#  '\\xfe\\xff\\x03',
#  '\\x10',
#  '\\xd4',
#  '\\x01',
#  '\\xdb',
#  '\\xe1',
#  '\\xfe\\xff\\x03',
#  '\\x11',
#  '\\xc6\\x08',
#  '\\x01',
#  '\\xc6\\x08',
#  '\\xc6\\x08',
#  '\\xfe\\xff\\x03',
#  '\\x14',
#  '\\xd4',
#  '\\x01',
#  '\\xdb',
#  '\\xe1',
#  '\\xfe\\xff\\x03',
#  '\\x15',
#  '\\xc6\\x08',
#  '\\x01',
#  '\\xc6\\x08',
#  '\\xc6\\x08',
#  'i',
#  '<',
#  'F',
#  '\\x01',
#  '\\xee',
#  '\\xf0',
#  '\\xfe',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xc5\\x01',
#  '\\xc7\\x01',
#  '\\xd4\\x01',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xe6\\xff\\xff\\xff\\xff\\xff\\xff\\xffD',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xc5\\x01',
#  'U\\x02',
#  '\\xd4\\x01',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xe6\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x88',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xc5\\x01',
#  '\\x83\\x02',
#  '\\xd4\\x01',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xe6\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xcc',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xc5\\x01',
#  '\\xb1\\x02',
#  '\\xd4\\x01',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xe6\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x10\\x01',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xc5\\x01',
#  '\\xdf\\x02',
#  '\\xd4\\x01',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xe6\\xff\\xff\\xff\\xff\\xff\\xff\\xffT\\x01',
#  '\\xff\\xff',
#  '\\x01',
#  '\\r\\x03',
#  '\\x0f\\x03',
#  '\\x1d\\x03',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\x98\\x01',
#  '\\xff\\xff',
#  '\\x01',
#  '\\x87\\x03',
#  '\\x89\\x03',
#  '\\x96\\x03',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\xdc\\x01',
#  '\\xff\\xff',
#  '\\x01',
#  '\\x12\\x04',
#  '\\x14\\x04',
#  '"\\x04',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff \\x02',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xaf\\x04',
#  '\\xb1\\x04',
#  '\\xbf\\x04',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xffd\\x02',
#  '\\xff\\xff',
#  '\\x01',
#  'v\\x05',
#  'x\\x05',
#  '\\x86\\x05',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\xa8\\x02',
#  '\\xff\\xff',
#  '\\x01',
#  '.\\x06',
#  '0\\x06',
#  '>\\x06',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x0c',
#  '\\xff\\xff\\xff\\xff\\xec\\x02',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xf7\\x06',
#  '\\xf9\\x06',
#  '\\x06\\x07',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff0\\x03',
#  '\\xff\\xff',
#  '\\x01',
#  '\\x86\\x07',
#  '\\x89\\x07',
#  '\\x96\\x07',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x02',
#  '\\xff\\xff\\xff\\xfft\\x03',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xd0\\x07',
#  '\\xd3\\x07',
#  '\\xe0\\x07',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\xb8\\x03',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xd0\\x07',
#  '\\xd3\\x07',
#  '\\xe0\\x07',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\xfc\\x03',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xcd\\x08',
#  '\\xd0\\x08',
#  '\\xe0\\x07',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff@\\x04',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xcd\\x08',
#  '\\xd0\\x08',
#  '\\xe0\\x07',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\x84\\x04',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xf6\\x08',
#  '\\xf9\\x08',
#  '\\x06\\t',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\xc8\\x04',
#  '\\xff\\xff',
#  '\\x01',
#  '\\x8b\\t',
#  '\\x8e\\t',
#  '\\x9b\\t',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x02',
#  '\\xff\\xff\\xff\\xff\\x0c\\x05',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xd5\\t',
#  '\\xd8\\t',
#  '\\xe5\\t',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x04',
#  '\\xff\\xff\\xff\\xffP\\x05',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xd5\\t',
#  '\\xd8\\t',
#  '\\xe5\\t',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x04',
#  '\\xff\\xff\\xff\\xff\\x94\\x05',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xa3\\n',
#  '\\xa6\\n',
#  '\\x96\\x07',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xe6\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xd8\\x05',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xa3\\n',
#  '\\xd3\\n',
#  '\\x96\\x07',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xe6\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x1c\\x06',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xa3\\n',
#  '\\x0b',
#  '\\x96\\x07',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xe6\\xff\\xff\\xff\\xff\\xff\\xff\\xff`\\x06',
#  '\\xff\\xff',
#  '\\x01',
#  '-\\x0b',
#  '0\\x0b',
#  '>\\x0b',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x03',
#  '\\xff\\xff\\xff\\xff\\xa4\\x06',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xd1\\x0b',
#  '\\xd4\\x0b',
#  '>\\x0b',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x03',
#  '\\xff\\xff\\xff\\xff\\xe8\\x06',
#  '\\xff\\xff',
#  '\\x01',
#  '\\x1b\\x0c',
#  '\\x1e\\x0c',
#  '\\x9b\\t',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff,\\x07',
#  '\\xff\\xff',
#  '\\x01',
#  'D\\x0c',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xffp\\x07',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xd7\\x0c',
#  '\\xda\\x0c',
#  '\\xe7\\x0c',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\xb4\\x07',
#  '\\xff\\xff',
#  '\\x01',
#  '\\x91\\r',
#  '0\\x06',
#  '>\\x06',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x0c',
#  '\\xff\\xff\\xff\\xff\\xf8\\x07',
#  '\\xff\\xff',
#  '\\x01',
#  '\\x94\\r',
#  '\\x97\\r',
#  '\\xbf\\x04',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff<\\x08',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xbf\\r',
#  '\\x14\\x04',
#  '"\\x04',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\x80\\x08',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xc2\\r',
#  '\\xc5\\r',
#  '\\xd2\\r',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xe6\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xc4\\x08',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xc2\\r',
#  'Y\\x0e',
#  '\\xd2\\r',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xe6\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x08\\t',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xc2\\r',
#  '\\x7f\\x0e',
#  '\\xd2\\r',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xe6\\xff\\xff\\xff\\xff\\xff\\xff\\xffL\\t',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xc2\\r',
#  '\\xad\\x0e',
#  '\\xd2\\r',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xe6\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x90\\t',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xd3\\x0e',
#  '\\xd6\\x0e',
#  '\\x1d\\x03',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\xd4\\t',
#  '\\xff\\xff',
#  '\\x01',
#  '\\x14\\x0f',
#  '\\x17\\x0f',
#  '$\\x0f',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\x18\\n',
#  '\\xff\\xff',
#  '\\x01',
#  '\\x9f\\x0f',
#  '\\xa2\\x0f',
#  '>\\x06',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x06',
#  '\\xff\\xff\\xff\\xff\\\\\\n',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xda\\x0f',
#  '\\xdd\\x0f',
#  '\\xeb\\x0f',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x02',
#  '\\xff\\xff\\xff\\xff\\xa0\\n',
#  '\\xff\\xff',
#  '\\x01',
#  '\\x84\\x10',
#  '\\x87\\x10',
#  '\\x94\\x10',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\xe4\\n',
#  '\\xff\\xff',
#  '\\x01',
#  '\\x84\\x10',
#  '\\x11',
#  '.\\x11',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x02',
#  '\\xff\\xff\\xff\\xff(\\x0b',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xb7\\x11',
#  '\\x11',
#  '.\\x11',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x02',
#  '\\xff\\xff\\xff\\xffl\\x0b',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xba\\x11',
#  '\\xbd\\x11',
#  '\\xca\\x11',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x02',
#  '\\xff\\xff\\xff\\xff\\xb0\\x0b',
#  '\\xff\\xff',
#  '\\x01',
#  'L\\x12',
#  'O\\x12',
#  ']\\x12',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\xf4\\x0b',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xe6\\x12',
#  '\\xe9\\x12',
#  '\\x1d\\x03',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff8\\x0c',
#  '\\xff\\xff',
#  '\\x01',
#  '(\\x13',
#  '+\\x13',
#  '9\\x13',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff|\\x0c',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xbb\\x13',
#  '\\xbe\\x13',
#  '\\xcc\\x13',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\xc0\\x0c',
#  '\\xff\\xff',
#  '\\x01',
#  'I\\x14',
#  'L\\x14',
#  ']\\x12',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\x04\\r',
#  '\\xff\\xff',
#  '\\x01',
#  '\\x87\\x14',
#  '\\x8a\\x14',
#  '\\x98\\x14',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xffH\\r',
#  '\\xff\\xff',
#  '\\x01',
#  '\\x15',
#  '#\\x15',
#  '0\\x15',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\x8c\\r',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xbd\\x15',
#  '\\xc0\\x15',
#  '\\xcd\\x15',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\xd0\\r',
#  '\\xff\\xff',
#  '\\x01',
#  'L\\x16',
#  'O\\x16',
#  ']\\x16',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x02',
#  '\\xff\\xff\\xff\\xff\\x14\\x0e',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xef\\x16',
#  '\\xf2\\x16',
#  '\\xff\\x16',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xffX\\x0e',
#  '\\xff\\xff',
#  '\\x01',
#  '@\\x17',
#  'C\\x17',
#  '>\\x0b',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\x9c\\x0e',
#  '\\xff\\xff',
#  '\\x01',
#  '\\x81\\x17',
#  '\\x84\\x17',
#  '\\x91\\x17',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\xe0\\x0e',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xea\\x17',
#  '\\xed\\x17',
#  '\\xfa\\x17',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff$\\x0f',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xa5\\x18',
#  '\\xa8\\x18',
#  '\\x1d\\x03',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xffh\\x0f',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xe8\\x18',
#  '\\xeb\\x18',
#  '\\xf9\\x18',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\xac\\x0f',
#  '\\xff\\xff',
#  '\\x01',
#  'A\\x19',
#  'D\\x19',
#  'Q\\x19',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\xf0\\x0f',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xa2\\x19',
#  '\\xa5\\x19',
#  '\\xb3\\x19',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x02',
#  '\\xff\\xff\\xff\\xff4\\x10',
#  '\\xff\\xff',
#  '\\x01',
#  '\\x05\\x1a',
#  '\\x08\\x1a',
#  '>\\x06',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x03',
#  '\\xff\\xff\\xff\\xffx\\x10',
#  '\\xff\\xff',
#  '\\x01',
#  'H\\x1a',
#  'K\\x1a',
#  '\\x96\\x07',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x02',
#  '\\xff\\xff\\xff\\xff\\xbc\\x10',
#  '\\xff\\xff',
#  '\\x01',
#  '\\x86\\x1a',
#  '\\x89\\x1a',
#  '\\xb3\\x19',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x03',
#  '\\xff\\xff\\xff\\xff',
#  '\\x11',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xc1\\x1a',
#  '\\xc4\\x1a',
#  '\\x96\\x07',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xffD\\x11',
#  '\\xff\\xff',
#  '\\x01',
#  '\\x02\\x1b',
#  '\\x05\\x1b',
#  '\\x13\\x1b',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\x88\\x11',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xbc\\x1b',
#  '\\xbf\\x1b',
#  '\\xb3\\x19',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\xcc\\x11',
#  '\\xff\\xff',
#  '\\x01',
#  '\\xbc\\x1b',
#  '\\xf6\\x1b',
#  ']\\x12',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xff\\x10\\x12',
#  '\\xff\\xff',
#  '\\x01',
#  '0\\x1c',
#  '3\\x1c',
#  '\\x96\\x07',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x01',
#  '\\xff\\xff\\xff\\xffT\\x12',
#  '\\xff\\xff',
#  '\\x01',
#  '\\x0e',
#  '\\x0f',
#  '\\x1a',
#  '#',
#  '\\x02',
#  '\\xff\\xff\\xff\\xff5',
#  '>',
#  '\\x02',
#  '\\xff\\xff\\xff\\xffJ',
#  '>',
#  '\\x02',
#  '\\xff\\xff\\xff\\xffS',
#  '\\\\',
#  '\\x02',
#  '\\xff\\xff\\xff\\xffj',
#  '\\\\',
#  '\\x02',
#  '\\xff\\xff\\xff\\xffs',
#  '|',
#  '\\x02',
#  '\\xff\\xff\\xff\\xff\\x8a',
#  '\\x93',
#  '\\x02',
#  '\\xff\\xff\\xff\\xff\\xa5',
#  '\\x02',
#  '\\xff\\xff\\xff\\xff\\xae',
#  '\\x02',
#  '\\xff\\xff\\xff\\xff\\xb3',
#  '\\x02',
#  '\\xff\\xff\\xff\\xff\\xb9',
#  '\\\\',
#  '\\x02',
#  '\\xff\\xff\\xff\\xff\\xbe',
#  '#',
#  '\\x02',
#  '\\xff\\xff\\xff\\xff\\xc3',
#  '|',
#  '\\x02',
#  '\\xff\\xff\\xff\\xff\\xc8',
#  '>',
#  '\\x02',
#  '\\xff\\xff\\xff\\xff\\xcd',
#  '\\x93',
#  '\\x02',
#  '\\xff\\xff\\xff\\xffj',
#  '\\x04',
#  '\\x98\\x12',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff2\\x01',
#  '\\xff\\xff\\xff\\xff]\\x01',
#  ']\\x01',
#  '\\x16\\x01',
#  '\\x16\\x01',
#  'A\\x01',
#  '\\xfe',
#  'y\\x01',
#  '2\\x01',
#  '\\xfe',
#  ']\\x01',
#  '\\x16\\x01',
#  'A\\x01',
#  '\\xfe',
#  'y\\x01',
#  '\\x9d\\x01',
#  '\\xae\\x01',
#  '\\xf0',
#  '\\xf0',
#  '\\xf0',
#  '\\xb7\\x01',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xffM\\x02',
#  'M\\x02',
#  'M\\x02',
#  'M\\x02',
#  'M\\x02',
#  'M\\x02',
#  'M\\x02',
#  'M\\x02',
#  'M\\x02',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xf0\\x01',
#  '\\xff\\xff\\xff\\xff\\x0c\\x02',
#  '\\x0c\\x02',
#  '\\xde\\x01',
#  '\\xde\\x01',
#  '\\xfd\\x01',
#  '\\xd4\\x01',
#  '\\x1c\\x02',
#  '\\xf0\\x01',
#  '\\xd4\\x01',
#  '\\x0c\\x02',
#  '\\xde\\x01',
#  '\\xfd\\x01',
#  '\\xd4\\x01',
#  '\\x1c\\x02',
#  '4\\x02',
#  'D\\x02',
#  '\\xc7\\x01',
#  '\\xc7\\x01',
#  '\\xc7\\x01',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff{\\x02',
#  '{\\x02',
#  '{\\x02',
#  '{\\x02',
#  '{\\x02',
#  '{\\x02',
#  '{\\x02',
#  '{\\x02',
#  '{\\x02',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xf0\\x01',
#  '\\xff\\xff\\xff\\xff\\x0c\\x02',
#  '\\x0c\\x02',
#  '\\xde\\x01',
#  '\\xde\\x01',
#  '\\xfd\\x01',
#  '\\xd4\\x01',
#  '\\x1c\\x02',
#  '\\xf0\\x01',
#  '\\xd4\\x01',
#  '\\x0c\\x02',
#  '\\xde\\x01',
#  '\\xfd\\x01',
#  '\\xd4\\x01',
#  '\\x1c\\x02',
#  'b\\x02',
#  'r\\x02',
#  'U\\x02',
#  'U\\x02',
#  'U\\x02',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xa9\\x02',
#  '\\xa9\\x02',
#  '\\xa9\\x02',
#  '\\xa9\\x02',
#  '\\xa9\\x02',
#  '\\xa9\\x02',
#  '\\xa9\\x02',
#  '\\xa9\\x02',
#  '\\xa9\\x02',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xf0\\x01',
#  '\\xff\\xff\\xff\\xff\\x0c\\x02',
#  '\\x0c\\x02',
#  '\\xde\\x01',
#  '\\xde\\x01',
#  '\\xfd\\x01',
#  '\\xd4\\x01',
#  '\\x1c\\x02',
#  '\\xf0\\x01',
#  '\\xd4\\x01',
#  '\\x0c\\x02',
#  '\\xde\\x01',
#  '\\xfd\\x01',
#  '\\xd4\\x01',
#  '\\x1c\\x02',
#  '\\x90\\x02',
#  '\\xa0\\x02',
#  '\\x83\\x02',
#  '\\x83\\x02',
#  '\\x83\\x02',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xd7\\x02',
#  '\\xd7\\x02',
#  '\\xd7\\x02',
#  '\\xd7\\x02',
#  '\\xd7\\x02',
#  '\\xd7\\x02',
#  '\\xd7\\x02',
#  '\\xd7\\x02',
#  '\\xd7\\x02',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xf0\\x01',
#  '\\xff\\xff\\xff\\xff\\x0c\\x02',
#  '\\x0c\\x02',
#  '\\xde\\x01',
#  '\\xde\\x01',
#  '\\xfd\\x01',
#  '\\xd4\\x01',
#  '\\x1c\\x02',
#  '\\xf0\\x01',
#  '\\xd4\\x01',
#  '\\x0c\\x02',
#  '\\xde\\x01',
#  '\\xfd\\x01',
#  '\\xd4\\x01',
#  '\\x1c\\x02',
#  '\\xbe\\x02',
#  '\\xce\\x02',
#  '\\xb1\\x02',
#  '\\xb1\\x02',
#  '\\xb1\\x02',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x05\\x03',
#  '\\x05\\x03',
#  '\\x05\\x03',
#  '\\x05\\x03',
#  '\\x05\\x03',
#  '\\x05\\x03',
#  '\\x05\\x03',
#  '\\x05\\x03',
#  '\\x05\\x03',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xf0\\x01',
#  '\\xff\\xff\\xff\\xff\\x0c\\x02',
#  '\\x0c\\x02',
#  '\\xde\\x01',
#  '\\xde\\x01',
#  '\\xfd\\x01',
#  '\\xd4\\x01',
#  '\\x1c\\x02',
#  '\\xf0\\x01',
#  '\\xd4\\x01',
#  '\\x0c\\x02',
#  '\\xde\\x01',
#  '\\xfd\\x01',
#  '\\xd4\\x01',
#  '\\x1c\\x02',
#  '\\xec\\x02',
#  '\\xfc\\x02',
#  '\\xdf\\x02',
#  '\\xdf\\x02',
#  '\\xdf\\x02',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x1d\\x03',
#  '\\xff\\xff\\xff\\xffC\\x03',
#  'C\\x03',
#  '$\\x03',
#  '$\\x03',
#  '2\\x03',
#  '\\x1d\\x03',
#  '\\x1d\\x03',
#  '\\x1d\\x03',
#  '\\x1d\\x03',
#  'C\\x03',
#  '$\\x03',
#  '2\\x03',
#  '\\x1d\\x03',
#  '\\x1d\\x03',
#  'R\\x03',
#  'c\\x03',
#  '\\x0f\\x03',
#  '\\x0f\\x03',
#  '\\x0f\\x03',
#  'l\\x03',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xb2\\x03',
#  '\\xff\\xff\\xff\\xff\\xcf\\x03',
#  '\\xcf\\x03',
#  '\\xa4\\x03',
#  '\\xa4\\x03',
#  '\\xbe\\x03',
#  '\\x96\\x03',
#  '\\xe1\\x03',
#  '\\xb2\\x03',
#  '\\x96\\x03',
#  '\\xcf\\x03',
#  '\\xa4\\x03',
#  '\\xbe\\x03',
#  '\\x96\\x03',
#  '\\xe1\\x03',
#  '\\xf9\\x03',
#  '\\t\\x04',
#  '\\x89\\x03',
#  '\\x89\\x03',
#  '\\x89\\x03',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff;\\x04',
#  '\\xff\\xff\\xff\\xffX\\x04',
#  'X\\x04',
#  '-\\x04',
#  '-\\x04',
#  'J\\x04',
#  '"\\x04',
#  'e\\x04',
#  ';\\x04',
#  '"\\x04',
#  'X\\x04',
#  '-\\x04',
#  'J\\x04',
#  '"\\x04',
#  'e\\x04',
#  'y\\x04',
#  '\\x8a\\x04',
#  '\\x14\\x04',
#  '\\x14\\x04',
#  '\\x14\\x04',
#  '\\x93\\x04',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xef\\x04',
#  '\\xff\\xff\\xff\\xff\\x1a\\x05',
#  '\\x1a\\x05',
#  '\\xd4\\x04',
#  '\\xd4\\x04',
#  '\\x05',
#  '\\xbf\\x04',
#  '8\\x05',
#  '\\xef\\x04',
#  '\\xbf\\x04',
#  '\\x1a\\x05',
#  '\\xd4\\x04',
#  '\\x05',
#  '\\xbf\\x04',
#  '8\\x05',
#  'T\\x05',
#  'e\\x05',
#  '\\xb1\\x04',
#  '\\xb1\\x04',
#  '\\xb1\\x04',
#  'n\\x05',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xb2\\x05',
#  '\\xff\\xff\\xff\\xff\\xdb\\x05',
#  '\\xdb\\x05',
#  '\\x98\\x05',
#  '\\x98\\x05',
#  '\\xc6\\x05',
#  '\\x86\\x05',
#  '\\xf3\\x05',
#  '\\xb2\\x05',
#  '\\x86\\x05',
#  '\\xdb\\x05',
#  '\\x98\\x05',
#  '\\xc6\\x05',
#  '\\x86\\x05',
# ...
#  '\\xff\\xff\\xff\\xffM\\x18',
#  'M\\x18',
#  '\\x0f\\x18',
#  '\\x0f\\x18',
#  '6\\x18',
#  '\\xfa\\x17',
#  'k\\x18',
#  '*\\x18',
#  '\\xfa\\x17',
#  'M\\x18',
#  '\\x0f\\x18',
#  '6\\x18',
#  '\\xfa\\x17',
#  'k\\x18',
#  '\\x8c\\x18',
#  '\\x9c\\x18',
#  '\\xed\\x17',
#  '\\xed\\x17',
#  '\\xed\\x17',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x1d\\x03',
#  '\\xff\\xff\\xff\\xffC\\x03',
#  'C\\x03',
#  '$\\x03',
#  '$\\x03',
#  '2\\x03',
#  '\\x1d\\x03',
#  '\\x1d\\x03',
#  '\\x1d\\x03',
#  '\\x1d\\x03',
#  'C\\x03',
#  '$\\x03',
#  '2\\x03',
#  '\\x1d\\x03',
#  '\\x1d\\x03',
#  '\\xb6\\x18',
#  '\\xc7\\x18',
#  '\\xa8\\x18',
#  '\\xa8\\x18',
#  '\\xa8\\x18',
#  '\\xd0\\x18',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\x07\\x19',
#  '\\xff\\xff\\xff\\xff\\x1d\\x19',
#  '\\x1d\\x19',
#  '\\xfd\\x18',
#  '\\xfd\\x18',
#  '\\x14\\x19',
#  '\\xf9\\x18',
#  '"\\x19',
#  '\\x07\\x19',
#  '\\xf9\\x18',
#  '\\x1d\\x19',
#  '\\xfd\\x18',
#  '\\x14\\x19',
#  '\\xf9\\x18',
#  '"\\x19',
#  "\\'\\x19",
#  '8\\x19',
#  '\\xeb\\x18',
#  '\\xeb\\x18',
#  '\\xeb\\x18',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff`\\x19',
#  '\\xff\\xff\\xff\\xffu\\x19',
#  'u\\x19',
#  'X\\x19',
#  'X\\x19',
#  'k\\x19',
#  'Q\\x19',
#  '\\x7f\\x19',
#  '`\\x19',
#  'Q\\x19',
#  'u\\x19',
#  'X\\x19',
#  'k\\x19',
#  'Q\\x19',
#  '\\x7f\\x19',
#  '\\x89\\x19',
#  '\\x99\\x19',
#  'D\\x19',
#  'D\\x19',
#  'D\\x19',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xbe\\x19',
#  '\\xff\\xff\\xff\\xff\\xca\\x19',
#  '\\xca\\x19',
#  '\\xb7\\x19',
#  '\\xb7\\x19',
#  '\\xc5\\x19',
#  '\\xb3\\x19',
#  '\\xd1\\x19',
#  '\\xbe\\x19',
#  '\\xb3\\x19',
#  '\\xca\\x19',
#  '\\xb7\\x19',
#  '\\xc5\\x19',
#  '\\xb3\\x19',
#  '\\xd1\\x19',
#  '\\xdb\\x19',
#  '\\xec\\x19',
#  '\\xa5\\x19',
#  '\\xa5\\x19',
#  '\\xa5\\x19',
#  '\\xf5\\x19',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xffi\\x06',
#  '\\xff\\xff\\xff\\xff\\x92\\x06',
#  '\\x92\\x06',
#  'R\\x06',
#  'R\\x06',
#  '{\\x06',
#  '>\\x06',
#  '\\xaf\\x06',
#  'i\\x06',
#  '>\\x06',
#  '\\x92\\x06',
#  'R\\x06',
#  '{\\x06',
#  '>\\x06',
#  '\\xaf\\x06',
#  '\\x16\\x1a',
#  "\\'\\x1a",
#  '\\x08\\x1a',
#  '\\x08\\x1a',
#  '\\x08\\x1a',
#  '0\\x1a',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xa2\\x07',
#  '\\xff\\xff\\xff\\xff\\xaa\\x07',
#  '\\xaa\\x07',
#  '\\x9b\\x07',
#  '\\x9b\\x07',
#  '\\xaa\\x07',
#  '\\x96\\x07',
#  '\\xb0\\x07',
#  '\\xa2\\x07',
#  '\\x96\\x07',
#  '\\xaa\\x07',
#  '\\x9b\\x07',
#  '\\xaa\\x07',
#  '\\x96\\x07',
#  '\\xb0\\x07',
#  'Y\\x1a',
#  'j\\x1a',
#  'K\\x1a',
#  'K\\x1a',
#  'K\\x1a',
#  's\\x1a',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xbe\\x19',
#  '\\xff\\xff\\xff\\xff\\xca\\x19',
#  '\\xca\\x19',
#  '\\xb7\\x19',
#  '\\xb7\\x19',
#  '\\xc5\\x19',
#  '\\xb3\\x19',
#  '\\xd1\\x19',
#  '\\xbe\\x19',
#  '\\xb3\\x19',
#  '\\xca\\x19',
#  '\\xb7\\x19',
#  '\\xc5\\x19',
#  '\\xb3\\x19',
#  '\\xd1\\x19',
#  '\\x97\\x1a',
#  '\\xa8\\x1a',
#  '\\x89\\x1a',
#  '\\x89\\x1a',
#  '\\x89\\x1a',
#  '\\xb1\\x1a',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xa2\\x07',
#  '\\xff\\xff\\xff\\xff\\xaa\\x07',
#  '\\xaa\\x07',
#  '\\x9b\\x07',
#  '\\x9b\\x07',
#  '\\xaa\\x07',
#  '\\x96\\x07',
#  '\\xb0\\x07',
#  '\\xa2\\x07',
#  '\\x96\\x07',
#  '\\xaa\\x07',
#  '\\x9b\\x07',
#  '\\xaa\\x07',
#  '\\x96\\x07',
#  '\\xb0\\x07',
#  '\\xd2\\x1a',
#  '\\xe3\\x1a',
#  '\\xc4\\x1a',
#  '\\xc4\\x1a',
#  '\\xc4\\x1a',
#  '\\xec\\x1a',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff@\\x1b',
#  '\\xff\\xff\\xff\\xffm\\x1b',
#  'm\\x1b',
#  '!\\x1b',
#  '!\\x1b',
#  'O\\x1b',
#  '\\x13\\x1b',
#  '\\x8a\\x1b',
#  '@\\x1b',
#  '\\x13\\x1b',
#  'm\\x1b',
#  '!\\x1b',
#  'O\\x1b',
#  '\\x13\\x1b',
#  '\\x8a\\x1b',
#  '\\xa2\\x1b',
#  '\\xb3\\x1b',
#  '\\x05\\x1b',
#  '\\x05\\x1b',
#  '\\x05\\x1b',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xbe\\x19',
#  '\\xff\\xff\\xff\\xff\\xca\\x19',
#  '\\xca\\x19',
#  '\\xb7\\x19',
#  '\\xb7\\x19',
#  '\\xc5\\x19',
#  '\\xb3\\x19',
#  '\\xd1\\x19',
#  '\\xbe\\x19',
#  '\\xb3\\x19',
#  '\\xca\\x19',
#  '\\xb7\\x19',
#  '\\xc5\\x19',
#  '\\xb3\\x19',
#  '\\xd1\\x19',
#  '\\xcd\\x1b',
#  '\\xde\\x1b',
#  '\\xbf\\x1b',
#  '\\xbf\\x1b',
#  '\\xbf\\x1b',
#  '\\xe7\\x1b',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xffz\\x12',
#  '\\xff\\xff\\xff\\xff\\x97\\x12',
#  '\\x97\\x12',
#  'j\\x12',
#  'j\\x12',
#  '\\x87\\x12',
#  ']\\x12',
#  '\\xa5\\x12',
#  'z\\x12',
#  ']\\x12',
#  '\\x97\\x12',
#  'j\\x12',
#  '\\x87\\x12',
#  ']\\x12',
#  '\\xa5\\x12',
#  '\\x04\\x1c',
#  '\\x15\\x1c',
#  '\\xf6\\x1b',
#  '\\xf6\\x1b',
#  '\\xf6\\x1b',
#  '\\x1e\\x1c',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xa2\\x07',
#  '\\xff\\xff\\xff\\xff\\xaa\\x07',
#  '\\xaa\\x07',
#  '\\x9b\\x07',
#  '\\x9b\\x07',
#  '\\xaa\\x07',
#  '\\x96\\x07',
#  '\\xb0\\x07',
#  '\\xa2\\x07',
#  '\\x96\\x07',
#  '\\xaa\\x07',
#  '\\x9b\\x07',
#  '\\xaa\\x07',
#  '\\x96\\x07',
#  '\\xb0\\x07',
#  'A\\x1c',
#  'R\\x1c',
#  '3\\x1c',
#  '3\\x1c',
#  '3\\x1c',
#  '[\\x1c',
#  '\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff\\xff']

# %% [markdown]
# Records are identified by a numeric "Serial Number". We find the start index of each record. The check is now more specific: a short, purely numeric field. This prevents long numeric fields (like Reference Numbers) from being incorrectly marked as a new record start.

# %%
start_indices = []

# Use enumerate() to get both the index (i) and the value (field) for each item.
for i, field in enumerate(all_fields):
    
    # This is the same condition as in the list comprehension.
    # It checks if the field is a number AND is short.
    if field.isdigit() and len(field) < 4:
        
        # If the conditions are met, add the index 'i' to our list.
        start_indices.append(i)

pprint(start_indices)
# Out:
# [0,
#  11,
#  38,
#  47,
#  57,
#  68,
#  79,
#  89,
#  100,
#  110,
#  119,
#  131,
#  135,
#  145,
#  155,
#  166,
#  179,
#  190,
#  195,
#  199,
#  206,
#  216,
#  217,
#  221,
#  222,
#  242,
#  247,
#  257,
#  262,
#  272,
#  293,
#  294,
#  304,
#  315,
#  320,
#  331,
#  341,
#  346,
#  357,
#  367,
#  377,
#  388,
#  398,
#  403,
#  413,
#  423,
#  428,
#  438,
#  448,
#  459,
#  464,
#  469,
#  474,
#  479,
#  489,
#  498]

# %% [markdown]
# Processes a single record's data (a "chunk") and maps its fields to the defined CSV columns using pattern matching and positional logic.
#
# Args:
#     chunk (list): A list of strings representing one record, starting with a serial number.
#
# Returns:
#     dict: A dictionary with keys matching the CSV headers and values from the chunk.

# %%
def process_chunk(chunk):
    
    # --- Step 3: Field Mapping and Logic ---
    headers = [
        "Serial Number", "Part Number", "Part Name English", 
        "Part Name Language 1", "Part Name Language 2", "Part Name Language 3", 
        "Part Name Language 4", "Part Name Language 5", 
        "Part Number in Other Format", "Reference Number", 
        "Additional Information", "Extra Data"
    ]
    record = {h: '' for h in headers}
    
    # The first item in a chunk is always the Serial Number.
    record['Serial Number'] = chunk[0]
    data_fields = chunk[1:]

    # Handle empty records (like #22, #24)
    if not data_fields:
        return record

    # Regex to identify part numbers with dots (e.g., "X530.108.146.000")
    # and reference numbers (e.g., "72311106").
    part_num_other_format_regex = re.compile(r'^[A-Z0-9\.]+$')
    ref_num_regex = re.compile(r'^[0-9]{8,}$') # Reference numbers are typically long

    # The first field is usually the Part Number, but not always (e.g., record #20).
    # We will tentatively assign it and correct it later if needed.
    current_pos = 0
    if current_pos < len(data_fields):
        record['Part Number'] = data_fields[current_pos]
        current_pos += 1

    # Consume all name/description fields. The sequence of names ends when we encounter
    # a field that strongly matches the pattern of a formatted part number or a reference number.
    names_end_pos = current_pos
    for i in range(current_pos, len(data_fields)):
        field = data_fields[i]
        is_formatted_part_num = bool(part_num_other_format_regex.match(field) and '.' in field)
        is_ref_num = bool(ref_num_regex.match(field))
        
        # This condition marks the end of the variable-length name fields.
        if is_formatted_part_num or is_ref_num:
            break
        names_end_pos += 1
    
    names = data_fields[current_pos:names_end_pos]
    
    # Handle special case for record #20 which has no part number.
    if record['Serial Number'] == '20':
        names.insert(0, record['Part Number']) # The tentative part number was actually the first name.
        record['Part Number'] = ''
        
    # Assign the collected names to the appropriate columns.
    name_headers = headers[2:8] # "Part Name English" through "Part Name Language 5"
    for i, name in enumerate(names):
        if i < len(name_headers):
            record[name_headers[i]] = name
            
    current_pos = names_end_pos

    # Sequentially assign the next fields based on their patterns.
    # Part Number in Other Format
    if current_pos < len(data_fields) and part_num_other_format_regex.match(data_fields[current_pos]) and '.' in data_fields[current_pos]:
        record['Part Number in Other Format'] = data_fields[current_pos]
        current_pos += 1
    
    # Reference Number
    if current_pos < len(data_fields) and ref_num_regex.match(data_fields[current_pos]):
        record['Reference Number'] = data_fields[current_pos]
        current_pos += 1
        
    # Additional Information is the single next field, if it exists.
    if current_pos < len(data_fields):
        record['Additional Information'] = data_fields[current_pos]
        current_pos += 1

    # --- Step 4: Handling Extra Data ---
    
    # Special case: Delete "white noise" from position 61. 
    # These data have no sense and most probably are distractor
    if record['Serial Number'] == '61':
        data_fields[current_pos:] = []
    
    # Any remaining fields are considered "Extra Data" and are joined with '___'.
    extra_data = data_fields[current_pos:]
    if extra_data:
        record['Extra Data'] = '___'.join(extra_data)
    else:
        record['Extra Data'] = '-' # Use a placeholder if no extra data exists.
        
    return record

# %% [markdown]
# Deviding 'all_fields' into chunks based on the identified record start indices. Each chunk represents one complete record. Applying 'process_chunk' to each chunk to transform it into a structured dictionary.

# %%
records_data = []
for i in range(len(start_indices)):
    start = start_indices[i]
    # The end of a chunk is the start of the next one, or the end of the file.
    end = start_indices[i + 1] if i + 1 < len(start_indices) else len(all_fields)
    chunk = all_fields[start:end]
    if chunk:
        records_data.append(process_chunk(chunk))

pprint(records_data)
# Out:
# [{'Additional Information': 'DIN472 - 90X3',
#   'Extra Data': '-',
#   'Part Name English': 'INTERNAL RETAINING RING',
#   'Part Name Language 1': "ANNEAU D\\'ARRET POUR ALESAGE",
#   'Part Name Language 2': 'INNENHALTERING',
#   'Part Name Language 3': 'ANELLO DI SICUREZZA INTERNO',
#   'Part Name Language 4': 'ANILLO DE RETENCION INTERNO',
#   'Part Name Language 5': 'PIER\\xc5\\x9aCIE\\xc5\\x83 USTALAJ\\xc4\\x84CY '
#                           'WEWN\\xc4\\x98TRZNY',
#   'Part Number': 'X530108146000',
#   'Part Number in Other Format': 'X530.108.146.000',
#   'Reference Number': '72311106',
#   'Serial Number': '1'},
#  {'Additional Information': '0,10 MM',
#   'Extra Data': '139100150131___139.100.150.131___72316228___0,15 '
#                 'MM___139100150132___139.100.150.132___72316229___0,25 '
#                 'MM___139100150133___139.100.150.133___72316230___0,30 '
#                 'MM___139100150134___139.100.150.134___72316231___0,80 MM',
#   'Part Name English': 'SHIM RING',
#   'Part Name Language 1': 'ANNEAU ENTRETOISE',
#   'Part Name Language 2': 'UNTERLEGRING',
#   'Part Name Language 3': 'DISCO SPESSORE',
#   'Part Name Language 4': 'ANILLO DE CALCE',
#   'Part Name Language 5': 'PIER\\xc5\\x9aCIE\\xc5\\x83 REGULACYJNY',
#   'Part Number': '139100150130',
#   'Part Number in Other Format': '139.100.150.130',
#   'Reference Number': '72316227',
#   'Serial Number': '2'},
#  {'Additional Information': '82,14X3,53-NBR 70 FWN56402',
#   'Extra Data': '-',
#   'Part Name English': 'O-RING',
#   'Part Name Language 1': 'JOINT TORIQUE',
#   'Part Name Language 2': 'GIUNTO DI TENUTA',
#   'Part Name Language 3': 'JUNTA TOROIDAL',
#   'Part Name Language 4': '',
#   'Part Name Language 5': '',
#   'Part Number': 'X548967266000',
#   'Part Number in Other Format': 'X548.967.266.000',
#   'Reference Number': '72313499',
#   'Serial Number': '3'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': 'SEALING COVER',
#   'Part Name Language 1': 'CACHE ETANCHE',
#   'Part Name Language 2': 'DICHTDECKEL',
#   'Part Name Language 3': 'COPERTURA TENUTA',
#   'Part Name Language 4': 'CUBIERTA SELLANTE',
#   'Part Name Language 5': 'POKRYWA USZCZELNIAJ\\xc4\\x84CA',
#   'Part Number': '178100010020',
#   'Part Number in Other Format': '178.100.010.020',
#   'Reference Number': '72393065',
#   'Serial Number': '4'},
#  {'Additional Information': 'FWN65500-DGS40X56X8/10WDF02',
#   'Extra Data': '-',
#   'Part Name English': 'SHAFT SEAL',
#   'Part Name Language 1': "JOINT D\\'ARBRE",
#   'Part Name Language 2': 'WELLENDICHTUNG',
#   'Part Name Language 3': 'TENUTA ALBERO',
#   'Part Name Language 4': 'SELLO DE EJE',
#   'Part Name Language 5': 'USZCZELNIENIE WA\\xc5\\x81U',
#   'Part Number': 'X550081705000',
#   'Part Number in Other Format': 'X550.081.705.000',
#   'Reference Number': '72430070',
#   'Serial Number': '5'},
#  {'Additional Information': 'DIN 720',
#   'Extra Data': '-',
#   'Part Name English': 'TAPER ROLLER BEARING',
#   'Part Name Language 1': 'PALIER A ROULEMENT CONIQUE',
#   'Part Name Language 2': 'KEGELROLLENLAGER',
#   'Part Name Language 3': 'CUSCINETTO A RULLI CONICI',
#   'Part Name Language 4': 'RODAMIENTO DE RODILLOS CONICO',
#   'Part Name Language 5': '\\xc5\\x81O\\xc5\\xbbYSKO ROLKOWE STO\\xc5\\xbbKOWE',
#   'Part Number': 'X619049041009',
#   'Part Number in Other Format': 'X619.049.041.009',
#   'Reference Number': '72317208',
#   'Serial Number': '6'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': 'DIFFERENTIAL LOCK',
#   'Part Name Language 1': 'VERROUILLAGE DIFFERENTIEL',
#   'Part Name Language 2': 'DIFFERENTIAL SPERRE',
#   'Part Name Language 3': 'BLOCCO DIFFERENZIALE',
#   'Part Name Language 4': 'BLOQUEO DEL DIFERENCIAL',
#   'Part Name Language 5': 'BLOKADA MECHANIZMU R\\xc3\\x93\\xc5\\xbbNICOWEGO',
#   'Part Number': 'H238104010040',
#   'Part Number in Other Format': 'H238.104.010.040',
#   'Reference Number': '72359217',
#   'Serial Number': '7'},
#  {'Additional Information': 'DIN 933 M12X25 GWA-10.9',
#   'Extra Data': '-',
#   'Part Name English': 'HEXAGONAL HEAD BOLT',
#   'Part Name Language 1': 'VIS A T\\xc3\\x8aTE HEXAGONALE',
#   'Part Name Language 2': 'SECHSKANTSCHRAUBE',
#   'Part Name Language 3': 'VITE A TESTA ESAGONALE',
#   'Part Name Language 4': 'TORNILLO DE CABEZA HEXAGONAL',
#   'Part Name Language 5': '\\xc5\\x9aRUBA SZE\\xc5\\x9aCIOK\\xc4\\x84TNA',
#   'Part Number': 'X487535406000',
#   'Part Number in Other Format': 'X487.535.406.000',
#   'Reference Number': '72374463',
#   'Serial Number': '8'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': 'BEARING FLANGE',
#   'Part Name Language 1': 'FLASQUE ROULEMENT',
#   'Part Name Language 2': 'LAGERFLANSCH',
#   'Part Name Language 3': 'FLANGIA DEL CUSCINETTO',
#   'Part Name Language 4': 'BRIDA DE COJINETE',
#   'Part Name Language 5': 'KRYZA \\xc5\\x81O\\xc5\\xbbYSKA',
#   'Part Number': '278110011030',
#   'Part Number in Other Format': '278.110.011.030',
#   'Reference Number': '72403994',
#   'Serial Number': '9'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': 'DISC',
#   'Part Name Language 1': 'DISQUE',
#   'Part Name Language 2': 'SCHEIBE',
#   'Part Name Language 3': 'DISCO',
#   'Part Name Language 4': 'TARCZA',
#   'Part Name Language 5': '',
#   'Part Number': '514100010130',
#   'Part Number in Other Format': '514.100.010.130',
#   'Reference Number': '72317260',
#   'Serial Number': '10'},
#  {'Additional Information': '*22\\n<-- U148.100.110  1X',
#   'Extra Data': 'SERBLK',
#   'Part Name English': 'DIFFERENTIAL SIDE GEAR',
#   'Part Name Language 1': 'ENGRENAGE LAT\\xc3\\x89RAL DE DIFF\\xc3\\x89RENTIEL',
#   'Part Name Language 2': 'ACHSKEGELRAD',
#   'Part Name Language 3': 'INGRANAGGIO SATELLITE DIFFERENZIALE',
#   'Part Name Language 4': 'ENGRANAJE LATERAL DIFERENCIAL',
#   'Part Name Language 5': 'KO\\xc5\\x81O Z\\xc4\\x98BATE BOCZNE MECHANIZMU '
#                           'R\\xc3\\x93\\xc5\\xbbNIC.',
#   'Part Number': '278110011050',
#   'Part Number in Other Format': '278.110.011.050',
#   'Reference Number': '72403996',
#   'Serial Number': '11'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': '',
#   'Part Name Language 1': '',
#   'Part Name Language 2': '',
#   'Part Name Language 3': '',
#   'Part Name Language 4': '',
#   'Part Name Language 5': '',
#   'Part Number': '278110011040',
#   'Part Number in Other Format': '278.110.011.040',
#   'Reference Number': '72403995',
#   'Serial Number': '12'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': 'CROSS BEARING',
#   'Part Name Language 1': 'PALIER TRANSVERSAL',
#   'Part Name Language 2': 'KREUZLAGER',
#   'Part Name Language 3': 'CUSCINETTO CROCIERA',
#   'Part Name Language 4': 'RODAMIENTO TRANSVERSAL',
#   'Part Name Language 5': '\\xc5\\x81O\\xc5\\xbbYSKO POPRZECZNE',
#   'Part Number': '178100010040',
#   'Part Number in Other Format': '178.100.010.040',
#   'Reference Number': '72316723',
#   'Serial Number': '13'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': 'AXLE',
#   'Part Name Language 1': 'ESSIEU',
#   'Part Name Language 2': 'ACHSE',
#   'Part Name Language 3': 'ASSALE',
#   'Part Name Language 4': 'EJE',
#   'Part Name Language 5': 'O\\xc5\\x9a',
#   'Part Number': '199100010020',
#   'Part Number in Other Format': '199.100.010.020',
#   'Reference Number': '72310138',
#   'Serial Number': '14'},
#  {'Additional Information': '*11\\n<-- U148.100.110  1X',
#   'Extra Data': '-',
#   'Part Name English': 'DIFFERENTIAL PINION',
#   'Part Name Language 1': 'PIGNON DE DIFF\\xc3\\x89RENTIEL',
#   'Part Name Language 2': 'AUSGLEICHSKEGELRAD',
#   'Part Name Language 3': 'PIGNONE DIFFERENZIALE',
#   'Part Name Language 4': 'PINON DEL DIFERENCIAL',
#   'Part Name Language 5': 'Z\\xc4\\x98BNIK MECHANIZMU '
#                           'R\\xc3\\x93\\xc5\\xbbNICOWEGO',
#   'Part Number': '278110011120',
#   'Part Number in Other Format': '278.110.011.120',
#   'Reference Number': '72312406',
#   'Serial Number': '15'},
#  {'Additional Information': '1,0 MM',
#   'Extra Data': '514100010110___514.100.010.110___72317258___1,2 '
#                 'MM___514100010120___514.100.010.120___72317259___1,5 MM',
#   'Part Name English': '',
#   'Part Name Language 1': '',
#   'Part Name Language 2': '',
#   'Part Name Language 3': '',
#   'Part Name Language 4': '',
#   'Part Name Language 5': '',
#   'Part Number': '514100010100',
#   'Part Number in Other Format': '514.100.010.100',
#   'Reference Number': '72317257',
#   'Serial Number': '16'},
#  {'Additional Information': 'ISO8752 5X30-ST VDA42',
#   'Extra Data': '-',
#   'Part Name English': 'TENSIONING PIN',
#   'Part Name Language 1': 'BROCHE DE TENSIONNEMENT',
#   'Part Name Language 2': 'SPANNSTIFT',
#   'Part Name Language 3': 'PERNO TENSIONE',
#   'Part Name Language 4': 'PERNO TENSOR',
#   'Part Name Language 5': 'TRZPIE\\xc5\\x83 ROZPR\\xc4\\x98\\xc5\\xbbNY',
#   'Part Number': 'X500621846000',
#   'Part Number in Other Format': 'X500.621.846.000',
#   'Reference Number': '72313811',
#   'Serial Number': '17'},
#  {'Additional Information': 'ISO8752-3X30-A-ST-OB3 FWN10256',
#   'Extra Data': '-',
#   'Part Name English': '',
#   'Part Name Language 1': '',
#   'Part Name Language 2': '',
#   'Part Name Language 3': '',
#   'Part Name Language 4': '',
#   'Part Name Language 5': '',
#   'Part Number': 'X500610446000',
#   'Part Number in Other Format': 'X500.610.446.000',
#   'Reference Number': '72313798',
#   'Serial Number': '18'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': '',
#   'Part Name Language 1': '',
#   'Part Name Language 2': '',
#   'Part Name Language 3': '',
#   'Part Name Language 4': '',
#   'Part Name Language 5': '',
#   'Part Number': '210103011040',
#   'Part Number in Other Format': '210.103.011.040',
#   'Reference Number': '72435674',
#   'Serial Number': '19'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': 'SIEHE WECHSELGETRIEBE',
#   'Part Name Language 1': 'SEE GEAR BOX (CHANGE-SPEED)',
#   'Part Name Language 2': 'VER CAJA DE CAMBIOS',
#   'Part Name Language 3': 'VOIR BOITE DE VITESSE',
#   'Part Name Language 4': 'VEDI CAMBIO',
#   'Part Name Language 5': 'PATRZ SKRZYNIA BIEG\\xc3\\x93W (ZMIANA '
#                           'BIEG\\xc3\\x93W)',
#   'Part Number': '',
#   'Part Number in Other Format': '',
#   'Reference Number': '',
#   'Serial Number': '20'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': 'DIFFERENTIAL HOUSING',
#   'Part Name Language 1': 'CARTER DE DIFF\\xc3\\x89RENTIEL',
#   'Part Name Language 2': 'DIFFERENTIALGEH\\xc3\\x84USE',
#   'Part Name Language 3': 'SCATOLA DIFFERENZIALE',
#   'Part Name Language 4': 'ALOJAMIENTO DIFERENCIAL',
#   'Part Name Language 5': 'OBUDOWA MECHANIZMU R\\xc3\\x93\\xc5\\xbbNICOWEGO',
#   'Part Number': '168109010010',
#   'Part Number in Other Format': '168.109.010.010',
#   'Reference Number': '72392781',
#   'Serial Number': '21'},
#  {'Additional Information': '',
#   'Extra Data': '',
#   'Part Name English': '',
#   'Part Name Language 1': '',
#   'Part Name Language 2': '',
#   'Part Name Language 3': '',
#   'Part Name Language 4': '',
#   'Part Name Language 5': '',
#   'Part Number': '',
#   'Part Number in Other Format': '',
#   'Reference Number': '',
#   'Serial Number': '22'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': '',
#   'Part Name Language 1': '',
#   'Part Name Language 2': '',
#   'Part Name Language 3': '',
#   'Part Name Language 4': '',
#   'Part Name Language 5': '',
#   'Part Number': 'X623138320000',
#   'Part Number in Other Format': 'X623.138.320.000',
#   'Reference Number': '72378806',
#   'Serial Number': '23'},
#  {'Additional Information': '',
#   'Extra Data': '',
#   'Part Name English': '',
#   'Part Name Language 1': '',
#   'Part Name Language 2': '',
#   'Part Name Language 3': '',
#   'Part Name Language 4': '',
#   'Part Name Language 5': '',
#   'Part Number': '',
#   'Part Number in Other Format': '',
#   'Reference Number': '',
#   'Serial Number': '24'},
#  {'Additional Information': '178100010051',
#   'Extra Data': '178.100.010.051___72393068___178100010052___178.100.010.052___72393069___0,20 '
#                 'MM___178100010053___178.100.010.053___72393070',
#   'Part Name English': 'KEYED WASHER',
#   'Part Name Language 1': 'RONDELLE CLAVET\\xc3\\x89E',
#   'Part Name Language 2': 'EINSTELLSCHEIBE',
#   'Part Name Language 3': 'RONDELLA MASCHIATA',
#   'Part Name Language 4': 'ARANDELA ENCHAVETADA',
#   'Part Name Language 5': 'PODK\\xc5\\x81ADKA Z WYPUSTEM',
#   'Part Number': '178100010050',
#   'Part Number in Other Format': '178.100.010.050',
#   'Reference Number': '72393067',
#   'Serial Number': '25'},
#  {'Additional Information': '101X3-NBR 70 FWN56402',
#   'Extra Data': '-',
#   'Part Name English': '',
#   'Part Name Language 1': '',
#   'Part Name Language 2': '',
#   'Part Name Language 3': '',
#   'Part Name Language 4': '',
#   'Part Name Language 5': '',
#   'Part Number': 'X549284566000',
#   'Part Number in Other Format': 'X549.284.566.000',
#   'Reference Number': '72376717',
#   'Serial Number': '26'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': 'BEARING CAP',
#   'Part Name Language 1': 'CHAPEAU DE PALIER',
#   'Part Name Language 2': 'LAGERKAPPE',
#   'Part Name Language 3': 'CAPPELLO DEL SUPPORTO',
#   'Part Name Language 4': 'TAPA DE COJINETE',
#   'Part Name Language 5': 'POKRYWA \\xc5\\x81O\\xc5\\xbbYSKA',
#   'Part Number': '205100011091',
#   'Part Number in Other Format': '205.100.011.091',
#   'Reference Number': '72397528',
#   'Serial Number': '27'},
#  {'Additional Information': 'M10 X 35 CL10.9',
#   'Extra Data': '-',
#   'Part Name English': '',
#   'Part Name Language 1': '',
#   'Part Name Language 2': '',
#   'Part Name Language 3': '',
#   'Part Name Language 4': '',
#   'Part Name Language 5': '',
#   'Part Number': 'X487531806000',
#   'Part Number in Other Format': 'X487.531.806.000',
#   'Reference Number': '72315688',
#   'Serial Number': '28'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': 'SOCKET HEAD BOLT',
#   'Part Name Language 1': 'BOULON \\xc3\\x80 T\\xc3\\x8aTE CREUSE',
#   'Part Name Language 2': 'ZYLINDERSCHRAUBE',
#   'Part Name Language 3': 'BULLONE CON TESTA A BRUGOLA',
#   'Part Name Language 4': 'PERNO DE CABEZA HEXAGONAL',
#   'Part Name Language 5': '\\xc5\\x9aRUBA IMBUSOWA',
#   'Part Number': 'X493613205000',
#   'Part Number in Other Format': 'X493.613.205.000',
#   'Reference Number': '72315778',
#   'Serial Number': '29'},
#  {'Additional Information': '<>34\\n<>',
#   'Extra Data': 'X418852204000___DOWEL PIN___TENON DE '
#                 'GUIDAGE___PASSSTIFT___SPINA DI CENTRAGGIO___PASADOR DE '
#                 'ESPIGA___KO\\xc5\\x81EK '
#                 'USTALAJ\\xc4\\x84CY___X418.852.204.000___72372672___DIN '
#                 '1474-8X20-ST',
#   'Part Name English': 'SHIFT FORK',
#   'Part Name Language 1': 'FOURCHETTE DE D\\xc3\\x89BRAYAGE',
#   'Part Name Language 2': 'SCHALTGABEL',
#   'Part Name Language 3': 'FORCHETTA DEL CAMBIO',
#   'Part Name Language 4': 'HORQUILLA EMBRAGUE',
#   'Part Name Language 5': 'WIDE\\xc5\\x81KI WYBIERAKA',
#   'Part Number': '258100010080',
#   'Part Number in Other Format': '258.100.010.080',
#   'Reference Number': '72401949',
#   'Serial Number': '33'},
#  {'Additional Information': '',
#   'Extra Data': '',
#   'Part Name English': '',
#   'Part Name Language 1': '',
#   'Part Name Language 2': '',
#   'Part Name Language 3': '',
#   'Part Name Language 4': '',
#   'Part Name Language 5': '',
#   'Part Number': '',
#   'Part Number in Other Format': '',
#   'Reference Number': '',
#   'Serial Number': '34'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': 'SLIDING MEMBER',
#   'Part Name Language 1': 'DISPOSITIF DE GLISSAGE',
#   'Part Name Language 2': 'GLEITSTEIN',
#   'Part Name Language 3': 'MEMBRO SCORREVOLE',
#   'Part Name Language 4': 'ELEMENTO DESLIZANTE',
#   'Part Name Language 5': 'ELEMENT \\xc5\\x9aLIZGOWY',
#   'Part Number': '238104010240',
#   'Part Number in Other Format': '238.104.010.240',
#   'Reference Number': '72399554',
#   'Serial Number': '35'},
#  {'Additional Information': 'DIN 915 M12X20-45H',
#   'Extra Data': '-',
#   'Part Name English': 'THREADED PIN',
#   'Part Name Language 1': 'BROCHE FILET\\xc3\\x89E',
#   'Part Name Language 2': 'GEWINDESTIFT',
#   'Part Name Language 3': 'PERNO FILETTATO',
#   'Part Name Language 4': 'PERNO ROSCADO',
#   'Part Name Language 5': 'SWORZE\\xc5\\x83 GWINTOWANY',
#   'Part Number': 'X413425806000',
#   'Part Number in Other Format': 'X413.425.806.000',
#   'Reference Number': '72372595',
#   'Serial Number': '36'},
#  {'Additional Information': '18X2,5-NBR 70 FWN56402',
#   'Extra Data': '-',
#   'Part Name English': '',
#   'Part Name Language 1': '',
#   'Part Name Language 2': '',
#   'Part Name Language 3': '',
#   'Part Name Language 4': '',
#   'Part Name Language 5': '',
#   'Part Number': 'X548854466000',
#   'Part Number in Other Format': 'X548.854.466.000',
#   'Reference Number': '72313440',
#   'Serial Number': '37'},
#  {'Additional Information': 'DIN 6885 A8X5X36-C45K',
#   'Extra Data': '-',
#   'Part Name English': 'FITTING KEY',
#   'Part Name Language 1': 'CL\\xc3\\x89 DE FIXATION',
#   'Part Name Language 2': 'PASSFEDER',
#   'Part Name Language 3': 'LINGUETTA',
#   'Part Name Language 4': 'LLAVE DE ENCAJE',
#   'Part Name Language 5': 'KLUCZ MONTA\\xc5\\xbbOWY',
#   'Part Number': 'X446217334000',
#   'Part Number in Other Format': 'X446.217.334.000',
#   'Reference Number': '72373227',
#   'Serial Number': '38'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': 'BLOCKING LEVER',
#   'Part Name Language 1': 'LEVIER DE BLOCAGE',
#   'Part Name Language 2': 'SPERRHEBEL',
#   'Part Name Language 3': 'LEVA DI BLOCCO',
#   'Part Name Language 4': 'PALANCA DE BLOQUEO',
#   'Part Name Language 5': 'D\\xc5\\xb9WIGNIA BLOKUJ\\xc4\\x84CA',
#   'Part Number': 'H178109010023',
#   'Part Number in Other Format': 'H178.109.010.023',
#   'Reference Number': '72355684',
#   'Serial Number': '39'},
#  {'Additional Information': 'DIN 916 M14X16-45H',
#   'Extra Data': '-',
#   'Part Name English': '',
#   'Part Name Language 1': '',
#   'Part Name Language 2': '',
#   'Part Name Language 3': '',
#   'Part Name Language 4': '',
#   'Part Name Language 5': '',
#   'Part Number': 'X413627906000',
#   'Part Number in Other Format': 'X413.627.906.000',
#   'Reference Number': '72372608',
#   'Serial Number': '40'},
#  {'Additional Information': 'DIN 6325 6M6X36',
#   'Extra Data': '-',
#   'Part Name English': 'CYLINDER PIN',
#   'Part Name Language 1': 'GOUPILLE DE V\\xc3\\x89RIN',
#   'Part Name Language 2': 'ZYLINDERSTIFT',
#   'Part Name Language 3': 'PERNO CILINDRO',
#   'Part Name Language 4': 'PERNO DEL CILINDRO',
#   'Part Name Language 5': 'CZOP CYLINDRA',
#   'Part Number': 'X506240500000',
#   'Part Number in Other Format': 'X506.240.500.000',
#   'Reference Number': '72313870',
#   'Serial Number': '41'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': 'COMPRESSION SPRING',
#   'Part Name Language 1': 'RESSORT DE COMPRESSION',
#   'Part Name Language 2': 'DRUCKFEDER',
#   'Part Name Language 3': 'MOLLA COMPRESSIONE',
#   'Part Name Language 4': 'RESORTE DE COMPRESI\\xc3\\x93N',
#   'Part Name Language 5': 'SPR\\xc4\\x98\\xc5\\xbbYNA DOCISKOWA',
#   'Part Number': '016861050230',
#   'Part Number in Other Format': '016.861.050.230',
#   'Reference Number': '72386498',
#   'Serial Number': '42'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': 'PRESSURE SWITCH',
#   'Part Name Language 1': 'MANOCONTACT',
#   'Part Name Language 2': 'DRUCKSCHALTER',
#   'Part Name Language 3': 'PRESSOSTATO',
#   'Part Name Language 4': 'INTERRUPTOR DE PRESION',
#   'Part Name Language 5': 'PRZE\\xc5\\x81\\xc4\\x84CZNIK CI\\xc5\\x9aNIENIA',
#   'Part Number': '178109360010',
#   'Part Number in Other Format': '178.109.360.010',
#   'Reference Number': '72393606',
#   'Serial Number': '43'},
#  {'Additional Information': 'DIN 7603 A12X18-CU',
#   'Extra Data': '-',
#   'Part Name English': 'SEALING WASHER',
#   'Part Name Language 1': 'RONDELLE ETANCH.',
#   'Part Name Language 2': 'DICHTRING',
#   'Part Name Language 3': 'RONDELLA ERMETIC',
#   'Part Name Language 4': 'ARANDELA SELLO',
#   'Part Name Language 5': 'PODK\\xc5\\x81ADKA USZCZELNIAJ\\xc4\\x84CA',
#   'Part Number': 'X540003878000',
#   'Part Number in Other Format': 'X540.003.878.000',
#   'Reference Number': '72315093',
#   'Serial Number': '44'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': 'BOLT',
#   'Part Name Language 1': 'BOULON',
#   'Part Name Language 2': 'BOLZEN',
#   'Part Name Language 3': 'BULLONE',
#   'Part Name Language 4': 'PERNO',
#   'Part Name Language 5': '\\xc5\\x9aRUBA',
#   'Part Number': '178109010020',
#   'Part Number in Other Format': '178.109.010.020',
#   'Reference Number': '72393538',
#   'Serial Number': '45'},
#  {'Additional Information': 'ISO8752-6X50-A-ST-OB3',
#   'Extra Data': '-',
#   'Part Name English': '',
#   'Part Name Language 1': '',
#   'Part Name Language 2': '',
#   'Part Name Language 3': '',
#   'Part Name Language 4': '',
#   'Part Name Language 5': '',
#   'Part Number': 'X500625546000',
#   'Part Number in Other Format': 'X500.625.546.000',
#   'Reference Number': '72375154',
#   'Serial Number': '46'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': 'ECCENTRIC',
#   'Part Name Language 1': 'EXCENTRIQUE',
#   'Part Name Language 2': 'EXZENTER',
#   'Part Name Language 3': 'ECCENTRICO',
#   'Part Name Language 4': 'EXCENTRICO',
#   'Part Name Language 5': 'MIMO\\xc5\\x9aR\\xc3\\x93D',
#   'Part Number': '178109010011',
#   'Part Number in Other Format': '178.109.010.011',
#   'Reference Number': '72393537',
#   'Serial Number': '47'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': 'LUBRICATING OIL PIPE',
#   'Part Name Language 1': "TUYAU D\\'HUILE DE GRAISSAGE",
#   'Part Name Language 2': 'SCHMIERROHR',
#   'Part Name Language 3': 'TUBO DI LUBRIFICAZIONE',
#   'Part Name Language 4': 'TUBERIA DE ACEITE LUBRICACION',
#   'Part Name Language 5': 'PRZEW\\xc3\\x93D SZTYWNY OLEJU SMAROWEGO',
#   'Part Number': '380100010010',
#   'Part Number in Other Format': '380.100.010.010',
#   'Reference Number': '72408558',
#   'Serial Number': '50'},
#  {'Additional Information': '9,3X2,4-NBR 70 FWN56402',
#   'Extra Data': '-',
#   'Part Name English': '',
#   'Part Name Language 1': '',
#   'Part Name Language 2': '',
#   'Part Name Language 3': '',
#   'Part Name Language 4': '',
#   'Part Name Language 5': '',
#   'Part Number': 'X548823666000',
#   'Part Number in Other Format': 'X548.823.666.000',
#   'Reference Number': '72313418',
#   'Serial Number': '51'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': 'PAN',
#   'Part Name Language 1': 'RECEPTEUR',
#   'Part Name Language 2': 'AUFFANGWANNE',
#   'Part Name Language 3': 'PANNELLO',
#   'Part Name Language 4': 'CUBA',
#   'Part Name Language 5': 'MISA',
#   'Part Number': 'H205100011010',
#   'Part Number in Other Format': 'H205.100.011.010',
#   'Reference Number': '72357985',
#   'Serial Number': '52'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': 'BAFFLE',
#   'Part Name Language 1': 'CHICANE',
#   'Part Name Language 2': 'PRALLBLECH',
#   'Part Name Language 3': 'DEVIATORE',
#   'Part Name Language 4': 'DESVIADOR',
#   'Part Name Language 5': 'PRZEGRODA',
#   'Part Number': '205100011050',
#   'Part Number in Other Format': '205.100.011.050',
#   'Reference Number': '72397526',
#   'Serial Number': '53'},
#  {'Additional Information': 'DIN 936 M14-17H',
#   'Extra Data': '-',
#   'Part Name English': 'NUT',
#   'Part Name Language 1': '\\xc3\\x89CROU',
#   'Part Name Language 2': 'MUTTER',
#   'Part Name Language 3': 'DADO',
#   'Part Name Language 4': 'TUERCA',
#   'Part Name Language 5': 'NAKR\\xc4\\x98TKA',
#   'Part Number': 'X428803604000',
#   'Part Number in Other Format': 'X428.803.604.000',
#   'Reference Number': '72372883',
#   'Serial Number': '54'},
#  {'Additional Information': 'DIN 933-M6 X 16-8.8-A3L',
#   'Extra Data': '-',
#   'Part Name English': '',
#   'Part Name Language 1': '',
#   'Part Name Language 2': '',
#   'Part Name Language 3': '',
#   'Part Name Language 4': '',
#   'Part Name Language 5': '',
#   'Part Number': 'X487520041000',
#   'Part Number in Other Format': 'X487.520.041.000',
#   'Reference Number': '72315626',
#   'Serial Number': '55'},
#  {'Additional Information': 'DIN 125-6,4-ST.A3L',
#   'Extra Data': '-',
#   'Part Name English': '',
#   'Part Name Language 1': '',
#   'Part Name Language 2': '',
#   'Part Name Language 3': '',
#   'Part Name Language 4': '',
#   'Part Name Language 5': '',
#   'Part Number': 'X450005108000',
#   'Part Number in Other Format': 'X450.005.108.000',
#   'Reference Number': '72311787',
#   'Serial Number': '56'},
#  {'Additional Information': 'DIN 934 M6-8A3L',
#   'Extra Data': '-',
#   'Part Name English': '',
#   'Part Name Language 1': '',
#   'Part Name Language 2': '',
#   'Part Name Language 3': '',
#   'Part Name Language 4': '',
#   'Part Name Language 5': '',
#   'Part Number': 'X428202239000',
#   'Part Number in Other Format': 'X428.202.239.000',
#   'Reference Number': '72313266',
#   'Serial Number': '57'},
#  {'Additional Information': 'DIN9021-6,4-140HV-A3L',
#   'Extra Data': '-',
#   'Part Name English': '',
#   'Part Name Language 1': '',
#   'Part Name Language 2': '',
#   'Part Name Language 3': '',
#   'Part Name Language 4': '',
#   'Part Name Language 5': '',
#   'Part Number': 'X454305108000',
#   'Part Number in Other Format': 'X454.305.108.000',
#   'Reference Number': '72311822',
#   'Serial Number': '58'},
#  {'Additional Information': '',
#   'Extra Data': '-',
#   'Part Name English': 'OIL LUBE PIPE',
#   'Part Name Language 1': "TUYAU D\\'HUILE DE LUBRIFICATION",
#   'Part Name Language 2': '\\xc3\\x96LSCHMIERROHR',
#   'Part Name Language 3': 'TUBO DI LUBRIFICAZIONE A OLIO',
#   'Part Name Language 4': 'TUBERIA DE ACEITE LUBRICANTE',
#   'Part Name Language 5': 'RURKA SMAROWANIA OLEJEM',
#   'Part Number': 'H162160010010',
#   'Part Number in Other Format': 'H162.160.010.010',
#   'Reference Number': '72355006',
#   'Serial Number': '59'},
#  {'Additional Information': 'DIN 936 M8-17H',
#   'Extra Data': 'X413122106000___X413.122.106.000___72372576___DIN 914 '
#                 'M8X35-45H',
#   'Part Name English': '',
#   'Part Name Language 1': '',
#   'Part Name Language 2': '',
#   'Part Name Language 3': '',
#   'Part Name Language 4': '',
#   'Part Name Language 5': '',
#   'Part Number': 'X428802404000',
#   'Part Number in Other Format': 'X428.802.404.000',
#   'Reference Number': '72372870',
#   'Serial Number': '60'},
#  {'Additional Information': 'DIN 125-8,4-ST.A3L',
#   'Extra Data': '-',
#   'Part Name English': '',
#   'Part Name Language 1': '',
#   'Part Name Language 2': '',
#   'Part Name Language 3': '',
#   'Part Name Language 4': '',
#   'Part Name Language 5': '',
#   'Part Number': 'X450006308000',
#   'Part Number in Other Format': 'X450.006.308.000',
#   'Reference Number': '72311788',
#   'Serial Number': '61'}]

# %% [markdown]
# Saving data in CSV file: "output_data/Output_File_01.csv"

# %%
if not records_data:
    print("No records to write.")
    
with open('output_data/output.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.DictWriter(f, fieldnames=records_data[0].keys())
    writer.writeheader()
    writer.writerows(records_data)
    print(f"Successfully parsed data and created output_data/output.csv")
# Out:
# Successfully parsed data and created output_data/output.csv
